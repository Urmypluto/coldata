# %%
! python -m pip install --upgrade pymilvus langchain openai tiktoken pymongo sentence-transformers

# %% [markdown]
# ## Milvus server setup

# %% [markdown]
# need to install and turn on the milvus server before running this code snippet.
#
# tutorial to install/run/stop milvus server:
# https://milvus.io/docs/install_standalone-docker.md

# %%
from os import environ

MILVUS_HOST = "localhost"
MILVUS_PORT = "19530"

# %% [markdown]
# ## Load data via MongoDB (with the ColAI client)

# %%
import pymongo
client = pymongo.MongoClient(
    "mongodb+srv://ColAccess:ColAI2023@crawl.xk12nv0.mongodb.net/?retryWrites=true&w=majority"
)
client.list_database_names()
# Out:
# ['Crawl', 'admin', 'local']

# %%
db = client['Crawl']
db.list_collection_names()
# Out:
# ['metadata']

# %%
collection = db['metadata']
files = list(collection.find())
files
# Out:
# [{'_id': ObjectId('64bb7c64bc23363224cb6651'),
#   'id': 'newspaper+and+magazine+images+segmentation+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/306/newspaper+and+magazine+images+segmentation+dataset',
#   'Title': 'Newspaper and magazine images segmentation dataset',
#   'Description': ' Dataset is well suited for segmentation tasks. It contains 101 scanned pages from different newspapers and magazines in Russian with ground truth pixel-based masks.',
#   'Dataset Characteristics': '-',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '101',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c65bc23363224cb6652'),
#   'id': 'rice+cammeo+and+osmancik',
#   'url': 'https://archive.ics.uci.edu/dataset/545/rice+cammeo+and+osmancik',
#   'Title': 'Rice (Cammeo and Osmancik)',
#   'Description': " A total of 3810 rice grain's images were taken for the two species, processed and feature inferences were made. 7 morphological features were obtained for each grain of rice.",
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '3810',
#   '# Attributes': '8'},
#  {'_id': ObjectId('64bb7c65bc23363224cb6653'),
#   'id': 'geo+magnetic+field+and+wlan+dataset+for+indoor+localisation+from+wristband+and+smartphone',
#   'url': 'https://archive.ics.uci.edu/dataset/377/geo+magnetic+field+and+wlan+dataset+for+indoor+localisation+from+wristband+and+smartphone',
#   'Title': 'Geo-Magnetic field and WLAN dataset for indoor localisation from wristband and smartphone',
#   'Description': ' A multisource and multivariate dataset for indoor localisation methods based on WLAN and Geo-Magnetic Ã¯Â¬Â\x81eld Ã¯Â¬Â\x81ngerprinting',
#   'Dataset Characteristics': 'Multivariate, Sequential, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Regression, Clustering',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '153540',
#   '# Attributes': '25'},
#  {'_id': ObjectId('64bb7c65bc23363224cb6654'),
#   'id': 'gas+sensor+array+under+dynamic+gas+mixtures',
#   'url': 'https://archive.ics.uci.edu/dataset/322/gas+sensor+array+under+dynamic+gas+mixtures',
#   'Title': 'Gas sensor array under dynamic gas mixtures',
#   'Description': ' The data set contains the recordings of 16 chemical sensors exposed to two dynamic gas mixtures at varying concentrations. For each mixture, signals were acquired continuously during 12 hours.',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '4178504',
#   '# Attributes': '19'},
#  {'_id': ObjectId('64bb7c65bc23363224cb6655'),
#   'id': 'movie',
#   'url': 'https://archive.ics.uci.edu/dataset/132/movie',
#   'Title': 'Movie',
#   'Description': ' This data set contains a list of over 10000 films including many older, odd, and cult films. There is information on actors, casts, directors, producers, studios, etc.',
#   'Dataset Characteristics': 'Multivariate, Relational',
#   'Subject Area': 'Other',
#   'Associated Tasks': '-',
#   'Attribute Type': '-',
#   '# Instances': '10000',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c65bc23363224cb6656'),
#   'id': 'ser+knowledge+modeling+data+students+knowledge+levels+on+dc+electrical+machines',
#   'url': 'https://archive.ics.uci.edu/dataset/263/ser+knowledge+modeling+data+students+knowledge+levels+on+dc+electrical+machines',
#   'Title': "ser Knowledge Modeling Data (Students' Knowledge Levels on DC Electrical Machines)",
#   'Description': " The dataset is about the users' learning activities and knowledge levels on subjects of DC  Electrical Machines. The dataset had been obtained from online web-courses  and reported in my Ph.D. Thesis.",
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '403',
#   '# Attributes': '5'},
#  {'_id': ObjectId('64bb7c65bc23363224cb6657'),
#   'id': 'university+of+tehran+question+dataset+2016+utqd+2016',
#   'url': 'https://archive.ics.uci.edu/dataset/425/university+of+tehran+question+dataset+2016+utqd+2016',
#   'Title': 'University of Tehran Question Dataset 2016 (UTQD.2016)',
#   'Description': ' Persian questions gathered from a jeopardy game broadcasted on Iranian national television. ',
#   'Dataset Characteristics': 'Text',
#   'Subject Area': 'Other',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '1175',
#   '# Attributes': '3'},
#  {'_id': ObjectId('64bb7c65bc23363224cb6658'),
#   'id': 'connectionist+bench+sonar+mines+vs+rocks',
#   'url': 'https://archive.ics.uci.edu/dataset/151/connectionist+bench+sonar+mines+vs+rocks',
#   'Title': 'Connectionist Bench (Sonar, Mines vs. Rocks)',
#   'Description': ' The task is to train a network to discriminate between sonar signals bounced off a metal cylinder and those bounced off a roughly cylindrical rock.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '208',
#   '# Attributes': '60'},
#  {'_id': ObjectId('64bb7c66bc23363224cb6659'),
#   'id': 'baum+1',
#   'url': 'https://archive.ics.uci.edu/dataset/473/baum+1',
#   'Title': 'BAUM-1',
#   'Description': ' BAUM-1 dataset contains 1184 multimodal facial video clips collected from 31 subjects. The 1184 video clips contain spontaneous facial expressions and speech of 13 emotional and mental states.',
#   'Dataset Characteristics': 'Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '1184',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c66bc23363224cb665a'),
#   'id': 'pandor',
#   'url': 'https://archive.ics.uci.edu/dataset/460/pandor',
#   'Title': 'PANDOR',
#   'Description': ' PANDOR is a novel and publicly available dataset for online recommendation provided by Purch (http://www.purch.com/). ',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Recommendation',
#   'Attribute Type': 'Categorical',
#   '# Instances': '-',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c66bc23363224cb665b'),
#   'id': 'noisyoffice',
#   'url': 'https://archive.ics.uci.edu/dataset/318/noisyoffice',
#   'Title': 'NoisyOffice',
#   'Description': ' Corpus intended to do cleaning (or binarization) and enhancement of noisy grayscale printed text images using supervised learning methods. Noisy images and their corresponding ground truth provided.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '216',
#   '# Attributes': '216'},
#  {'_id': ObjectId('64bb7c66bc23363224cb665c'),
#   'id': 'energy+efficiency',
#   'url': 'https://archive.ics.uci.edu/dataset/242/energy+efficiency',
#   'Title': 'Energy efficiency',
#   'Description': ' This study looked into assessing the heating load and cooling load requirements of buildings (that is, energy efficiency) as a function of building parameters.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Regression',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '768',
#   '# Attributes': '8'},
#  {'_id': ObjectId('64bb7c66bc23363224cb665d'),
#   'id': 'polish+companies+bankruptcy+data',
#   'url': 'https://archive.ics.uci.edu/dataset/365/polish+companies+bankruptcy+data',
#   'Title': 'Polish companies bankruptcy data',
#   'Description': ' The dataset is about bankruptcy prediction of Polish companies.The bankrupt companies were analyzed in the period 2000-2012, while the still operating companies were evaluated from 2007 to 2013.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Business',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '10503',
#   '# Attributes': '64'},
#  {'_id': ObjectId('64bb7c66bc23363224cb665e'),
#   'id': 'baum+2',
#   'url': 'https://archive.ics.uci.edu/dataset/474/baum+2',
#   'Title': 'BAUM-2',
#   'Description': ' A multilingual audio-visual affective face database consisting of 1047 video clips of 286 subjects. ',
#   'Dataset Characteristics': 'Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '1047',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c66bc23363224cb665f'),
#   'id': 'molecular+biology+splice+junction+gene+sequences',
#   'url': 'https://archive.ics.uci.edu/dataset/69/molecular+biology+splice+junction+gene+sequences',
#   'Title': 'Molecular Biology (Splice-junction Gene Sequences)',
#   'Description': ' Primate splice-junction gene sequences (DNA) with associated imperfect domain theory',
#   'Dataset Characteristics': 'Sequential, Domain-Theory',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Categorical',
#   '# Instances': '3190',
#   '# Attributes': '61'},
#  {'_id': ObjectId('64bb7c67bc23363224cb6660'),
#   'id': 'internet+advertisements',
#   'url': 'https://archive.ics.uci.edu/dataset/51/internet+advertisements',
#   'Title': 'Internet Advertisements',
#   'Description': ' This dataset represents a set of possible advertisements on Internet pages.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Categorical, Integer, Real',
#   '# Instances': '3279',
#   '# Attributes': '1558'},
#  {'_id': ObjectId('64bb7c67bc23363224cb6661'),
#   'id': 'roman+urdu+data+set',
#   'url': 'https://archive.ics.uci.edu/dataset/458/roman+urdu+data+set',
#   'Title': 'Roman Urdu Data Set',
#   'Description': ' Roman Urdu (the scripting style for Urdu language) is one of the limited resource languages.A data corpus comprising of more than 20000 records was collected.',
#   'Dataset Characteristics': 'Text',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '20000',
#   '# Attributes': '2'},
#  {'_id': ObjectId('64bb7c67bc23363224cb6662'),
#   'id': 'volcanoes+on+venus+jartool+experiment',
#   'url': 'https://archive.ics.uci.edu/dataset/142/volcanoes+on+venus+jartool+experiment',
#   'Title': 'Volcanoes on Venus - JARtool experiment',
#   'Description': ' The JARtool project was a pioneering effort to develop an automatic system for cataloging small volcanoes in the large set of Venus images returned by the Magellan spacecraft.',
#   'Dataset Characteristics': 'Image',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '-',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c67bc23363224cb6663'),
#   'id': 'dataset+for+adl+recognition+with+wrist+worn+accelerometer',
#   'url': 'https://archive.ics.uci.edu/dataset/283/dataset+for+adl+recognition+with+wrist+worn+accelerometer',
#   'Title': 'Dataset for ADL Recognition with Wrist-worn Accelerometer',
#   'Description': ' Recordings of 16 volunteers performing 14 Activities of Daily Living (ADL) while carrying a single wrist-worn tri-axial accelerometer.',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Clustering',
#   'Attribute Type': '-',
#   '# Instances': '-',
#   '# Attributes': '3'},
#  {'_id': ObjectId('64bb7c67bc23363224cb6664'),
#   'id': 'computer+hardware',
#   'url': 'https://archive.ics.uci.edu/dataset/29/computer+hardware',
#   'Title': 'Computer Hardware',
#   'Description': ' Relative CPU Performance Data, described in terms of its cycle time, memory size, etc.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Integer',
#   '# Instances': '209',
#   '# Attributes': '9'},
#  {'_id': ObjectId('64bb7c67bc23363224cb6665'),
#   'id': 'land+mines-1',
#   'url': 'https://archive.ics.uci.edu/dataset/763/land+mines-1',
#   'Title': 'Land Mines',
#   'Description': ' Detection of mines buried in the ground is very important in terms of safety of life and property. Many different methods have been used in this regard; however, it has not yet been possible to achieve 100% success. Mine detection process consists of sensor design, data analysis and decision algorithm phases. The magnetic anomaly method works according to the principle of measuring the anomalies resulting from the object in the magnetic field that disturbs the structure of it, the magnetic field, and the data obtained at this point are used to determine the conditions such as motion and position. The determination of parameters such as position, depth or direction of motion using magnetic anomaly has been carried out since 1970.',
#   'Dataset Characteristics': 'Tabular, Multivariate, Other',
#   'Subject Area': 'Engineering',
#   'Associated Tasks': 'Classification, Clustering',
#   'Attribute Type': 'Real, Integer',
#   '# Instances': '338',
#   '# Attributes': '4'},
#  {'_id': ObjectId('64bb7c67bc23363224cb6666'),
#   'id': 'wisdm+smartphone+and+smartwatch+activity+and+biometrics+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/507/wisdm+smartphone+and+smartwatch+activity+and+biometrics+dataset',
#   'Title': 'WISDM Smartphone and Smartwatch Activity and Biometrics Dataset ',
#   'Description': ' Contains accelerometer and gyroscope time-series sensor data collected from a smartphone and smartwatch as 51 test subjects perform 18 activities for 3 minutes each. ',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '15630426',
#   '# Attributes': '6'},
#  {'_id': ObjectId('64bb7c67bc23363224cb6667'),
#   'id': 'stock+keeping+units',
#   'url': 'https://archive.ics.uci.edu/dataset/531/stock+keeping+units',
#   'Title': 'Stock keeping units',
#   'Description': ' The dataset is provided by the Ã¢â\x82¬Å\x93Trialto Latvia LTDÃ¢â\x82¬Â\x9d, the third-party logistics operator. Each observation stands for a distinct type of item for sale. ',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Business',
#   'Associated Tasks': 'Clustering',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '2279',
#   '# Attributes': '9'},
#  {'_id': ObjectId('64bb7c68bc23363224cb6668'),
#   'id': 'emg+dataset+in+lower+limb',
#   'url': 'https://archive.ics.uci.edu/dataset/278/emg+dataset+in+lower+limb',
#   'Title': 'EMG dataset in Lower Limb',
#   'Description': ' 3 different exercises: sitting, standing and walking in the muscles: biceps femoris, vastus medialis, rectus femoris and semitendinosus addition to goniometry in the exercises.',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': '-',
#   'Attribute Type': 'Real',
#   '# Instances': '132',
#   '# Attributes': '5'},
#  {'_id': ObjectId('64bb7c68bc23363224cb6669'),
#   'id': 'cloud',
#   'url': 'https://archive.ics.uci.edu/dataset/155/cloud',
#   'Title': 'Cloud',
#   'Description': ' Little Documentation',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Physical',
#   'Associated Tasks': '-',
#   'Attribute Type': 'Real',
#   '# Instances': '1024',
#   '# Attributes': '10'},
#  {'_id': ObjectId('64bb7c68bc23363224cb666a'),
#   'id': 'mturk+user+perceived+clusters+over+images',
#   'url': 'https://archive.ics.uci.edu/dataset/416/mturk+user+perceived+clusters+over+images',
#   'Title': 'Mturk User-Perceived Clusters over Images',
#   'Description': " This dataset was collected by Shan-Hung Wu and DataLab members at NTHU, Taiwan. There're 325 user-perceived clusters from 100 users and their corresponding descriptions.",
#   'Dataset Characteristics': 'Multivariate, Text',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Clustering',
#   'Attribute Type': 'Integer',
#   '# Instances': '180',
#   '# Attributes': '500'},
#  {'_id': ObjectId('64bb7c68bc23363224cb666b'),
#   'id': 'ionosphere',
#   'url': 'https://archive.ics.uci.edu/dataset/52/ionosphere',
#   'Title': 'Ionosphere',
#   'Description': ' Classification of radar returns from the ionosphere',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '351',
#   '# Attributes': '34'},
#  {'_id': ObjectId('64bb7c68bc23363224cb666c'),
#   'id': 'perfume+data',
#   'url': 'https://archive.ics.uci.edu/dataset/303/perfume+data',
#   'Title': 'Perfume Data',
#   'Description': ' This data consists of odors of 20 different perfumes. Data was obtained by using a handheld odor meter (OMX-GR sensor) per second for 28 seconds period.',
#   'Dataset Characteristics': 'Univariate, Domain-Theory',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Clustering',
#   'Attribute Type': 'Integer',
#   '# Instances': '560',
#   '# Attributes': '2'},
#  {'_id': ObjectId('64bb7c68bc23363224cb666d'),
#   'id': 'eeg+database',
#   'url': 'https://archive.ics.uci.edu/dataset/121/eeg+database',
#   'Title': 'EEG Database',
#   'Description': ' This data arises from a large study to examine EEG correlates of genetic predisposition to alcoholism. It contains measurements from 64 electrodes placed on the scalp sampled at 256 Hz',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Life',
#   'Associated Tasks': '-',
#   'Attribute Type': 'Categorical, Integer, Real',
#   '# Instances': '122',
#   '# Attributes': '4'},
#  {'_id': ObjectId('64bb7c68bc23363224cb666e'),
#   'id': '3d+road+network+north+jutland+denmark',
#   'url': 'https://archive.ics.uci.edu/dataset/246/3d+road+network+north+jutland+denmark',
#   'Title': '3D Road Network (North Jutland, Denmark)',
#   'Description': ' 3D road network with highly accurate elevation information (+-20cm) from Denmark used in eco-routing and fuel/Co2-estimation routing algorithms.',
#   'Dataset Characteristics': 'Sequential, Text',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Regression, Clustering',
#   'Attribute Type': 'Real',
#   '# Instances': '434874',
#   '# Attributes': '4'},
#  {'_id': ObjectId('64bb7c69bc23363224cb666f'),
#   'id': 'wheat+kernels',
#   'url': 'https://archive.ics.uci.edu/dataset/596/wheat+kernels',
#   'Title': 'Wheat kernels',
#   'Description': ' Measurements of morphological descriptors  of wheat kernels from Punjab State. A machine Learning based technique was used to extract 15 features, all are real valued attributes',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '314',
#   '# Attributes': '15'},
#  {'_id': ObjectId('64bb7c69bc23363224cb6670'),
#   'id': 'mesothelioma+s+disease+data+set',
#   'url': 'https://archive.ics.uci.edu/dataset/351/mesothelioma+s+disease+data+set',
#   'Title': 'MesotheliomaÃ¢â\x82¬â\x84¢s disease data set ',
#   'Description': ' MesotheliomaÃ¢â\x82¬â\x84¢s disease data set were prepared at Dicle University Faculty of Medicine in Turkey.\nThree hundred and twenty-four Mesothelioma patient data. In the dataset, all samples have 34 features.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '324',
#   '# Attributes': '34'},
#  {'_id': ObjectId('64bb7c69bc23363224cb6671'),
#   'id': 'sgemm+gpu+kernel+performance',
#   'url': 'https://archive.ics.uci.edu/dataset/440/sgemm+gpu+kernel+performance',
#   'Title': 'SGEMM GPU kernel performance',
#   'Description': " Running times for multiplying two 2048 x 2048 matrices using a GPU OpenCL SGEMM kernel with varying parameters (using the library 'CLTune').",
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Integer',
#   '# Instances': '241600',
#   '# Attributes': '18'},
#  {'_id': ObjectId('64bb7c69bc23363224cb6672'),
#   'id': 'las+vegas+strip',
#   'url': 'https://archive.ics.uci.edu/dataset/397/las+vegas+strip',
#   'Title': 'Las Vegas Strip',
#   'Description': ' This dataset includes quantitative and categorical features from online reviews from 21 hotels located in Las Vegas Strip, extracted from TripAdvisor (http://www.tripadvisor.com).',
#   'Dataset Characteristics': '-',
#   'Subject Area': 'Business',
#   'Associated Tasks': 'Classification, Regression',
#   'Attribute Type': 'Integer',
#   '# Instances': '504',
#   '# Attributes': '20'},
#  {'_id': ObjectId('64bb7c69bc23363224cb6673'),
#   'id': 'semg+for+basic+hand+movements',
#   'url': 'https://archive.ics.uci.edu/dataset/313/semg+for+basic+hand+movements',
#   'Title': 'sEMG for Basic Hand movements',
#   'Description': " The sEMG for Basic Hand movements includes 2 databases of surface electromyographic signals of 6 hand movements using Delsys' EMG System. Healthy subjects conducted six daily life grasps.",
#   'Dataset Characteristics': 'Time-Series',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '3000',
#   '# Attributes': '2500'},
#  {'_id': ObjectId('64bb7c69bc23363224cb6674'),
#   'id': 'mex',
#   'url': 'https://archive.ics.uci.edu/dataset/500/mex',
#   'Title': 'MEx',
#   'Description': ' The MEx Multi-modal Exercise dataset contains data of 7 different\nphysiotherapy exercises, performed by 30 subjects recorded with 2 accelerometers,\na pressure mat and a depth camera.',
#   'Dataset Characteristics': 'Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Clustering',
#   'Attribute Type': 'Real',
#   '# Instances': '6262',
#   '# Attributes': '710'},
#  {'_id': ObjectId('64bb7c69bc23363224cb6675'),
#   'id': 'wikipedia+math+essentials',
#   'url': 'https://archive.ics.uci.edu/dataset/605/wikipedia+math+essentials',
#   'Title': 'Wikipedia Math Essentials',
#   'Description': ' Contains Wikipedia pages about popular mathematics topics and the edges describe the links from one page to another. Features describe the number of daily visits between 2019 and 2021 March.',
#   'Dataset Characteristics': 'Time-Series',
#   'Subject Area': 'Social',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '731',
#   '# Attributes': '1068'},
#  {'_id': ObjectId('64bb7c69bc23363224cb6676'),
#   'id': 'audiology+original',
#   'url': 'https://archive.ics.uci.edu/dataset/7/audiology+original',
#   'Title': 'Audiology (Original)',
#   'Description': ' Nominal audiology dataset from Baylor',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Categorical',
#   '# Instances': '226',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c6abc23363224cb6677'),
#   'id': 'dynamic+features+of+virusshare+executables',
#   'url': 'https://archive.ics.uci.edu/dataset/413/dynamic+features+of+virusshare+executables',
#   'Title': 'Dynamic Features of VirusShare Executables',
#   'Description': ' This dataset contains the dynamic features of 107,888 executables, collected by VirusShare from Nov/2010 to Jul/2014.',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Regression',
#   'Attribute Type': 'Integer',
#   '# Instances': '107888',
#   '# Attributes': '482'},
#  {'_id': ObjectId('64bb7c6abc23363224cb6678'),
#   'id': 'post+operative+patient',
#   'url': 'https://archive.ics.uci.edu/dataset/82/post+operative+patient',
#   'Title': 'Post-Operative Patient',
#   'Description': ' Dataset of patient features',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Categorical, Integer',
#   '# Instances': '90',
#   '# Attributes': '8'},
#  {'_id': ObjectId('64bb7c6abc23363224cb6679'),
#   'id': 'chemical+composition+of+ceramic+samples',
#   'url': 'https://archive.ics.uci.edu/dataset/583/chemical+composition+of+ceramic+samples',
#   'Title': 'Chemical Composition of Ceramic Samples',
#   'Description': ' Classify ceramic samples based on their chemical composition from energy dispersive X-ray fluorescence',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Classification, Clustering',
#   'Attribute Type': 'Real',
#   '# Instances': '88',
#   '# Attributes': '19'},
#  {'_id': ObjectId('64bb7c6abc23363224cb667a'),
#   'id': 'pmu+ud',
#   'url': 'https://archive.ics.uci.edu/dataset/469/pmu+ud',
#   'Title': 'PMU-UD',
#   'Description': ' The handwritten dataset was collected from 170 participants with a total of 5,180 numeral patterns. The dataset is named Prince Mohammad Bin Fahd University - Urdu/Arabic Database (PMU-UD). ',
#   'Dataset Characteristics': 'Univariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '5180',
#   '# Attributes': '9'},
#  {'_id': ObjectId('64bb7c6abc23363224cb667b'),
#   'id': 'quadruped+mammals',
#   'url': 'https://archive.ics.uci.edu/dataset/86/quadruped+mammals',
#   'Title': 'Quadruped Mammals',
#   'Description': '  The file animals.c is a data generator of structured instances representing quadruped animals',
#   'Dataset Characteristics': 'Multivariate, Data-Generator',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '-',
#   '# Attributes': '72'},
#  {'_id': ObjectId('64bb7c6abc23363224cb667c'),
#   'id': 'accelerometer+gyro+mobile+phone+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/755/accelerometer+gyro+mobile+phone+dataset',
#   'Title': 'accelerometer_gyro_mobile_phone_dataset',
#   'Description': ' data collected on 2022, in King Saud University in riyadh for recognizing human activities using mobile phone IMU sensors (Accelerometer, and Gyroscope). these activity is calssified to standing(stop), or walking.',
#   'Dataset Characteristics': 'Tabular, Sequential, Multivariate, Time-Series',
#   'Subject Area': 'Computer Science',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real, Categorical',
#   '# Instances': '31991',
#   '# Attributes': '8'},
#  {'_id': ObjectId('64bb7c6abc23363224cb667d'),
#   'id': 'myocardial+infarction+complications',
#   'url': 'https://archive.ics.uci.edu/dataset/579/myocardial+infarction+complications',
#   'Title': 'Myocardial infarction complications',
#   'Description': ' Prediction of myocardial infarction complications',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '1700',
#   '# Attributes': '111'},
#  {'_id': ObjectId('64bb7c6bbc23363224cb667e'),
#   'id': 'economic+sanctions',
#   'url': 'https://archive.ics.uci.edu/dataset/153/economic+sanctions',
#   'Title': 'Economic Sanctions',
#   'Description': ' Domain Theory on Economic Sanctions; Undocumented',
#   'Dataset Characteristics': 'Domain-Theory',
#   'Subject Area': 'Financial',
#   'Associated Tasks': '-',
#   'Attribute Type': '-',
#   '# Instances': '-',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c6bbc23363224cb667f'),
#   'id': 'qualitative+structure+activity+relationships',
#   'url': 'https://archive.ics.uci.edu/dataset/85/qualitative+structure+activity+relationships',
#   'Title': 'Qualitative Structure Activity Relationships',
#   'Description': ' Two sets of datasets are given: pyrimidines and triazines',
#   'Dataset Characteristics': 'Domain-Theory',
#   'Subject Area': 'Physical',
#   'Associated Tasks': '-',
#   'Attribute Type': '-',
#   '# Instances': '-',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c6bbc23363224cb6680'),
#   'id': 'intelligent+media+accelerometer+and+gyroscope+im+accgyro+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/578/intelligent+media+accelerometer+and+gyroscope+im+accgyro+dataset',
#   'Title': 'Intelligent Media Accelerometer and Gyroscope (IM-AccGyro) Dataset',
#   'Description': ' The IM-AccGyro dataset is devised to benchmark techniques dealing with human activity recognition based on inertial sensors. \n\t',
#   'Dataset Characteristics': 'Time-Series',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '800',
#   '# Attributes': '9'},
#  {'_id': ObjectId('64bb7c6bbc23363224cb6681'),
#   'id': 'condition+monitoring+of+hydraulic+systems',
#   'url': 'https://archive.ics.uci.edu/dataset/447/condition+monitoring+of+hydraulic+systems',
#   'Title': 'Condition monitoring of hydraulic systems',
#   'Description': ' The data set addresses the condition assessment of a hydraulic test rig based on multi sensor data. Four fault types are superimposed with several severity grades impeding selective quantification.',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '2205',
#   '# Attributes': '43680'},
#  {'_id': ObjectId('64bb7c6bbc23363224cb6682'),
#   'id': 'facebook+comment+volume+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/363/facebook+comment+volume+dataset',
#   'Title': 'Facebook Comment Volume Dataset',
#   'Description': ' Instances in this dataset contain features extracted from facebook posts. The task associated with the data is to predict how many comments the post will receive.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Other',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '40949',
#   '# Attributes': '54'},
#  {'_id': ObjectId('64bb7c6bbc23363224cb6683'),
#   'id': 'cuff+less+blood+pressure+estimation',
#   'url': 'https://archive.ics.uci.edu/dataset/340/cuff+less+blood+pressure+estimation',
#   'Title': 'Cuff-Less Blood Pressure Estimation',
#   'Description': ' This Data set provides preprocessed and cleaned vital signals which can be used in designing algorithms for cuff-less estimation of the blood pressure.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification, Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '12000',
#   '# Attributes': '3'},
#  {'_id': ObjectId('64bb7c6bbc23363224cb6684'),
#   'id': 'p53+mutants',
#   'url': 'https://archive.ics.uci.edu/dataset/188/p53+mutants',
#   'Title': 'p53 Mutants',
#   'Description': ' The goal is to model mutant p53 transcriptional activity (active vs inactive) based on data extracted from biophysical simulations.\n',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '16772',
#   '# Attributes': '5408'},
#  {'_id': ObjectId('64bb7c6cbc23363224cb6685'),
#   'id': 'cmu+face+images',
#   'url': 'https://archive.ics.uci.edu/dataset/124/cmu+face+images',
#   'Title': 'CMU Face Images',
#   'Description': ' This data consists of 640 black and white face images of people taken with varying pose (straight, left, right, up), expression (neutral, happy, sad, angry), eyes (wearing sunglasses or not), and size',
#   'Dataset Characteristics': 'Image',
#   'Subject Area': 'Other',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Integer',
#   '# Instances': '640',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c6cbc23363224cb6686'),
#   'id': 'simulated+falls+and+daily+living+activities+data+set',
#   'url': 'https://archive.ics.uci.edu/dataset/455/simulated+falls+and+daily+living+activities+data+set',
#   'Title': 'Simulated Falls and Daily Living Activities Data Set',
#   'Description': ' 20 falls and 16 daily living activities were performed by 17 volunteers with 5 repetitions while wearing 6 sensors (3.060 instances) that attached to their head, chest, waist, wrist, thigh and ankle.',
#   'Dataset Characteristics': 'Time-Series',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Integer',
#   '# Instances': '3060',
#   '# Attributes': '138'},
#  {'_id': ObjectId('64bb7c6cbc23363224cb6687'),
#   'id': 'micromass',
#   'url': 'https://archive.ics.uci.edu/dataset/253/micromass',
#   'Title': 'MicroMass',
#   'Description': ' A dataset to explore machine learning approaches for the identification of microorganisms from mass-spectrometry data.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '931',
#   '# Attributes': '1300'},
#  {'_id': ObjectId('64bb7c6cbc23363224cb6688'),
#   'id': 'sift10m',
#   'url': 'https://archive.ics.uci.edu/dataset/353/sift10m',
#   'Title': 'SIFT10M',
#   'Description': ' In SIFT10M, each data point is a SIFT feature which is extracted from Caltech-256 by the open source VLFeat library. The corresponding patches of the SIFT features are provided.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Causal-Discovery',
#   'Attribute Type': 'Integer',
#   '# Instances': '11164866',
#   '# Attributes': '128'},
#  {'_id': ObjectId('64bb7c6cbc23363224cb6689'),
#   'id': 'msnbc+com+anonymous+web+data',
#   'url': 'https://archive.ics.uci.edu/dataset/133/msnbc+com+anonymous+web+data',
#   'Title': 'MSNBC.com Anonymous Web Data',
#   'Description': ' This data describes the page visits of users who visited msnbc.com on September 28, 1999. Visits are recorded at the level of URL category (see description) and are recorded in time order.',
#   'Dataset Characteristics': 'Sequential',
#   'Subject Area': 'Computer',
#   'Associated Tasks': '-',
#   'Attribute Type': 'Categorical',
#   '# Instances': '989818',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c6cbc23363224cb668a'),
#   'id': 'wilt',
#   'url': 'https://archive.ics.uci.edu/dataset/285/wilt',
#   'Title': 'Wilt',
#   'Description': ' High-resolution Remote Sensing data set (Quickbird). Small number of training samples of diseased trees, large number for other land cover. Testing data set from stratified random sample of image.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '4889',
#   '# Attributes': '6'},
#  {'_id': ObjectId('64bb7c6cbc23363224cb668b'),
#   'id': 'microblogpcu',
#   'url': 'https://archive.ics.uci.edu/dataset/323/microblogpcu',
#   'Title': 'microblogPCU',
#   'Description': ' MicroblogPCU data is crawled from sina weibo microblog[http://weibo.com/]. This data can be used to study machine learning methods  as well as do some social network research. ',
#   'Dataset Characteristics': 'Multivariate, Univariate, Sequential, Text',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Causal-Discovery',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '221579',
#   '# Attributes': '20'},
#  {'_id': ObjectId('64bb7c6cbc23363224cb668c'),
#   'id': 'insurance+company+benchmark+coil+2000',
#   'url': 'https://archive.ics.uci.edu/dataset/125/insurance+company+benchmark+coil+2000',
#   'Title': 'Insurance Company Benchmark (COIL 2000)',
#   'Description': ' This data set used in the CoIL 2000 Challenge contains information on customers of an insurance company. The data consists of 86 variables and includes product usage data and socio-demographic data',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Social',
#   'Associated Tasks': 'Regression, Description',
#   'Attribute Type': 'Categorical, Integer',
#   '# Instances': '9000',
#   '# Attributes': '86'},
#  {'_id': ObjectId('64bb7c6dbc23363224cb668d'),
#   'id': 'machine+learning+based+zzalpha+ltd+stock+recommendations+2012+2014',
#   'url': 'https://archive.ics.uci.edu/dataset/337/machine+learning+based+zzalpha+ltd+stock+recommendations+2012+2014',
#   'Title': 'Machine Learning based ZZAlpha Ltd. Stock Recommendations 2012-2014',
#   'Description': ' The data here are the ZZAlphaÃ\x82Â® machine learning recommendations made for various US traded stock portfolios the morning of each day during the 3 year period Jan 1, 2012 - Dec 31, 2014.  ',
#   'Dataset Characteristics': 'Sequential, Time-Series',
#   'Subject Area': 'Business',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '314080',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7c6dbc23363224cb668e'),
#   'id': 'stock+portfolio+performance',
#   'url': 'https://archive.ics.uci.edu/dataset/390/stock+portfolio+performance',
#   'Title': 'Stock portfolio performance',
#   'Description': ' The data set of performances of weighted scoring stock portfolios are obtained with mixture design from the US stock market historical database.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Business',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '315',
#   '# Attributes': '12'},
#  {'_id': ObjectId('64bb7c6dbc23363224cb668f'),
#   'id': 'abscisic+acid+signaling+network',
#   'url': 'https://archive.ics.uci.edu/dataset/173/abscisic+acid+signaling+network',
#   'Title': 'Abscisic Acid Signaling Network',
#   'Description': ' The objective is to determine the set of boolean rules that describe the interactions of the nodes within this plant signaling network.  The dataset includes 300 separate boolean pseudodynamic simulations using an asynchronous update scheme. ',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Causal-Discovery',
#   'Attribute Type': 'Integer',
#   '# Instances': '300',
#   '# Attributes': '43'},
#  {'_id': ObjectId('64bb7c6dbc23363224cb6690'),
#   'id': 'predict+keywords+activities+in+a+online+social+media',
#   'url': 'https://archive.ics.uci.edu/dataset/276/predict+keywords+activities+in+a+online+social+media',
#   'Title': 'Predict keywords activities in a online social media',
#   'Description': ' The data from Twitter was collected during 360 consecutive days. It was done by querying 1497 English keywords sampled from Wikipedia. This dataset is proposed in a Learning to rank setting.',
#   'Dataset Characteristics': 'Multivariate, Sequential, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': '-',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '51',
#   '# Attributes': '35'},
#  {'_id': ObjectId('64bb7c6dbc23363224cb6691'),
#   'id': 'blogfeedback',
#   'url': 'https://archive.ics.uci.edu/dataset/304/blogfeedback',
#   'Title': 'BlogFeedback',
#   'Description': ' Instances in this dataset contain features extracted from blog posts. The task associated with the data is to predict how many comments the post will receive.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Social',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '60021',
#   '# Attributes': '281'},
#  {'_id': ObjectId('64bb7c6dbc23363224cb6692'),
#   'id': 'labeled+text+forum+threads+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/584/labeled+text+forum+threads+dataset',
#   'Title': 'Labeled Text Forum Threads Dataset',
#   'Description': ' The dataset is a collection of text forum threads with class labels reflects the reply quality to the Initial-Post, 3 for complete relevant, 2 for partially relevant, and 1 for irrelevant',
#   'Dataset Characteristics': 'Text',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Integer',
#   '# Instances': '200',
#   '# Attributes': '9'},
#  {'_id': ObjectId('64bb7c6dbc23363224cb6693'),
#   'id': 'statlog+shuttle',
#   'url': 'https://archive.ics.uci.edu/dataset/148/statlog+shuttle',
#   'Title': 'Statlog (Shuttle)',
#   'Description': ' The shuttle dataset contains 9 attributes all of which are numerical. Approximately 80% of the data belongs to class 1',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Integer',
#   '# Instances': '58000',
#   '# Attributes': '8'},
#  {'_id': ObjectId('64bb7c6ebc23363224cb6694'),
#   'id': 'echocardiogram',
#   'url': 'https://archive.ics.uci.edu/dataset/38/echocardiogram',
#   'Title': 'Echocardiogram',
#   'Description': ' Data for classifying if patients will survive for at least one year after a heart attack',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Categorical, Integer, Real',
#   '# Instances': '132',
#   '# Attributes': '12'},
#  {'_id': ObjectId('64bb7c6ebc23363224cb6695'),
#   'id': 'codon+usage',
#   'url': 'https://archive.ics.uci.edu/dataset/577/codon+usage',
#   'Title': 'Codon usage',
#   'Description': ' DNA codon usage frequencies of a large sample of diverse biological organisms from different taxa',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification, Clustering',
#   'Attribute Type': '-',
#   '# Instances': '13028',
#   '# Attributes': '69'},
#  {'_id': ObjectId('64bb7c6ebc23363224cb6696'),
#   'id': 'chess+king+rook+vs+king+knight',
#   'url': 'https://archive.ics.uci.edu/dataset/21/chess+king+rook+vs+king+knight',
#   'Title': 'Chess (King-Rook vs. King-Knight)',
#   'Description': ' Knight Pin Chess End-Game Database Creator',
#   'Dataset Characteristics': 'Multivariate, Data-Generator',
#   'Subject Area': 'Game',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Categorical, Integer',
#   '# Instances': '-',
#   '# Attributes': '22'},
#  {'_id': ObjectId('64bb7c6ebc23363224cb6697'),
#   'id': 'greenhouse+gas+observing+network',
#   'url': 'https://archive.ics.uci.edu/dataset/328/greenhouse+gas+observing+network',
#   'Title': 'Greenhouse Gas Observing Network',
#   'Description': ' Design an observing network to monitor emissions of a greenhouse gas (GHG) in California given time series of synthetic observations and tracers from weather model simulations.\n',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '2921',
#   '# Attributes': '5232'},
#  {'_id': ObjectId('64bb7c6ebc23363224cb6698'),
#   'id': 'university',
#   'url': 'https://archive.ics.uci.edu/dataset/104/university',
#   'Title': 'University',
#   'Description': ' Data in original (LISP-readable) form',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Other',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Categorical, Integer',
#   '# Instances': '285',
#   '# Attributes': '17'},
#  {'_id': ObjectId('64bb7c6ebc23363224cb6699'),
#   'id': 'kitsune+network+attack+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/516/kitsune+network+attack+dataset',
#   'Title': 'Kitsune Network Attack Dataset',
#   'Description': ' A cybersecurity dataset containing nine different network attacks on a commercial IP-based surveillance system and an IoT network. The dataset includes reconnaissance, MitM, DoS, and botnet attacks.',
#   'Dataset Characteristics': 'Multivariate, Sequential, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification, Clustering, Causal-Discovery',
#   'Attribute Type': 'Real',
#   '# Instances': '27170754',
#   '# Attributes': '7'},
#  {'_id': ObjectId('64bb7c6ebc23363224cb669a'),
#   'id': 'early+biomarkers+of+parkinson+s+disease+based+on+natural+connected+speech',
#   'url': 'https://archive.ics.uci.edu/dataset/392/early+biomarkers+of+parkinson+s+disease+based+on+natural+connected+speech',
#   'Title': 'Early biomarkers of Parkinsonâ\x80\x99s disease based on natural connected speech',
#   'Description': ' Predict a pattern of neurodegeneration in the dataset of speech features obtained from patients with early untreated ParkinsonÃ¢â\x82¬â\x84¢s disease and patients at high risk developing ParkinsonÃ¢â\x82¬â\x84¢s disease.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification, Regression',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '130',
#   '# Attributes': '65'},
#  {'_id': ObjectId('64bb7c6fbc23363224cb669b'),
#   'id': 'waveform+database+generator+version+2',
#   'url': 'https://archive.ics.uci.edu/dataset/108/waveform+database+generator+version+2',
#   'Title': 'Waveform Database Generator (Version 2)',
#   'Description': " CART book's waveform domains",
#   'Dataset Characteristics': 'Multivariate, Data-Generator',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '5000',
#   '# Attributes': '40'},
#  {'_id': ObjectId('64bb7c6fbc23363224cb669c'),
#   'id': 'first+order+theorem+proving',
#   'url': 'https://archive.ics.uci.edu/dataset/249/first+order+theorem+proving',
#   'Title': 'First-order theorem proving',
#   'Description': ' Given a theorem, predict which of five heuristics will give the fastest proof when used by a first-order prover. A sixth prediction declines to attempt a proof, should the theorem be too difficult.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '6118',
#   '# Attributes': '51'},
#  {'_id': ObjectId('64bb7c6fbc23363224cb669d'),
#   'id': 'nasarian+cad+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/557/nasarian+cad+dataset',
#   'Title': 'Nasarian CAD Dataset',
#   'Description': ' This dataset comprises records of 150 subjects (all male employees in Iran have visited the Abadan Occupational (Industrial) Medicine Clinic) and 52 features.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '150',
#   '# Attributes': '52'},
#  {'_id': ObjectId('64bb7c6fbc23363224cb669e'),
#   'id': 'reuters+21578+text+categorization+collection',
#   'url': 'https://archive.ics.uci.edu/dataset/137/reuters+21578+text+categorization+collection',
#   'Title': 'Reuters-21578 Text Categorization Collection',
#   'Description': ' This is a collection of documents that appeared on Reuters newswire in 1987. The documents were assembled and indexed with categories.',
#   'Dataset Characteristics': 'Text',
#   'Subject Area': 'Business',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Categorical',
#   '# Instances': '21578',
#   '# Attributes': '5'},
#  {'_id': ObjectId('64bb7c6fbc23363224cb669f'),
#   'id': 'naticusdroid+android+permissions+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/722/naticusdroid+android+permissions+dataset',
#   'Title': 'NATICUSdroid (Android Permissions) Dataset',
#   'Description': ' Contains permissions extracted from more than 29000 benign & malware Android apps released between 2010-2019.',
#   'Dataset Characteristics': 'Tabular',
#   'Subject Area': 'Computer Science',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '29333',
#   '# Attributes': '86'},
#  {'_id': ObjectId('64bb7c6fbc23363224cb66a0'),
#   'id': 'appliances+energy+prediction',
#   'url': 'https://archive.ics.uci.edu/dataset/374/appliances+energy+prediction',
#   'Title': 'Appliances energy prediction',
#   'Description': ' Experimental data used to create regression models of appliances energy use in a low energy building.',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '19735',
#   '# Attributes': '29'},
#  {'_id': ObjectId('64bb7c6fbc23363224cb66a1'),
#   'id': 'beijing+pm2+5+data',
#   'url': 'https://archive.ics.uci.edu/dataset/381/beijing+pm2+5+data',
#   'Title': 'Beijing PM2.5 Data',
#   'Description': ' This hourly data set contains the PM2.5 data of US Embassy in Beijing. Meanwhile, meteorological data from Beijing Capital International Airport are also included. ',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '43824',
#   '# Attributes': '13'},
#  {'_id': ObjectId('64bb7c6fbc23363224cb66a2'),
#   'id': 'gisette',
#   'url': 'https://archive.ics.uci.edu/dataset/170/gisette',
#   'Title': 'Gisette',
#   'Description': " GISETTE is a handwritten digit recognition problem. The problem is to separate the highly confusible digits '4' and '9'. This dataset is one of five datasets of the NIPS 2003 feature selection challenge.\n",
# ...
#   'Attribute Type': 'Real',
#   '# Instances': '528',
#   '# Attributes': '10'},
#  {'_id': ObjectId('64bb7cb5bc23363224cb68a6'),
#   'id': 'condition+based+maintenance+of+naval+propulsion+plants',
#   'url': 'https://archive.ics.uci.edu/dataset/316/condition+based+maintenance+of+naval+propulsion+plants',
#   'Title': 'Condition Based Maintenance of Naval Propulsion Plants',
#   'Description': ' Data have been generated from a sophisticated simulator of a Gas Turbines (GT), mounted on a Frigate characterized by a COmbined Diesel eLectric And Gas (CODLAG) propulsion plant type.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '11934',
#   '# Attributes': '16'},
#  {'_id': ObjectId('64bb7cb5bc23363224cb68a7'),
#   'id': 'swarm+behaviour',
#   'url': 'https://archive.ics.uci.edu/dataset/524/swarm+behaviour',
#   'Title': 'Swarm Behaviour',
#   'Description': " This dataset achieved from an online survey, which is run by UNSW, Australia. It contains three data of ' Flocking - Not Flocking', 'Aligned - Not Aligned', and 'Grouped - Not Grouped'.",
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '24017',
#   '# Attributes': '2400'},
#  {'_id': ObjectId('64bb7cb5bc23363224cb68a8'),
#   'id': 'estimation+of+obesity+levels+based+on+eating+habits+and+physical+condition',
#   'url': 'https://archive.ics.uci.edu/dataset/544/estimation+of+obesity+levels+based+on+eating+habits+and+physical+condition',
#   'Title': 'Estimation of obesity levels based on eating habits and physical condition ',
#   'Description': ' This dataset include data for the estimation of obesity levels in individuals from the countries of Mexico, Peru and Colombia, based on their eating habits and physical condition. ',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification, Regression, Clustering',
#   'Attribute Type': 'Integer',
#   '# Instances': '2111',
#   '# Attributes': '17'},
#  {'_id': ObjectId('64bb7cb5bc23363224cb68a9'),
#   'id': 'imagenet',
#   'url': 'https://archive.ics.uci.edu/dataset/693/imagenet',
#   'Title': 'ImageNet',
#   'Description': ' A well-known large-scale image classification dataset with between 1000 and 20000 class labels and multiple million images.',
#   'Dataset Characteristics': 'Image',
#   'Subject Area': 'Computer Science',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '14000000',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7cb6bc23363224cb68aa'),
#   'id': 'emg+data+for+gestures',
#   'url': 'https://archive.ics.uci.edu/dataset/481/emg+data+for+gestures',
#   'Title': 'EMG data for gestures',
#   'Description': ' These are files of raw EMG data recorded by MYO Thalmic bracelet',
#   'Dataset Characteristics': 'Time-Series',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '30000',
#   '# Attributes': '6'},
#  {'_id': ObjectId('64bb7cb6bc23363224cb68ab'),
#   'id': 'student+performance+on+an+entrance+examination',
#   'url': 'https://archive.ics.uci.edu/dataset/582/student+performance+on+an+entrance+examination',
#   'Title': 'Student Performance on an entrance examination',
#   'Description': ' This dataset contains data of the candidates who qualified the medical entrance examination for admission to medical colleges of Assam of a particular year and collected by Prof. Jiten Hazarika.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '666',
#   '# Attributes': '11'},
#  {'_id': ObjectId('64bb7cb6bc23363224cb68ac'),
#   'id': 'multivariate+gait+data',
#   'url': 'https://archive.ics.uci.edu/dataset/760/multivariate+gait+data',
#   'Title': 'Multivariate Gait Data',
#   'Description': ' Bilateral (left, right) joint angle (ankle, knee, hip) times series data collected from 10 healthy subjects under 3 walking conditions (unbraced, knee braced, ankle braced). For each condition, each subjectâ\x80\x99s data consists of 10 consecutive gait cycles.',
#   'Dataset Characteristics': 'Sequential, Multivariate, Time-Series',
#   'Subject Area': 'Life Science',
#   'Associated Tasks': 'Classification, Regression, Clustering',
#   'Attribute Type': 'Real, Categorical, Integer',
#   '# Instances': '181800',
#   '# Attributes': '7'},
#  {'_id': ObjectId('64bb7cb6bc23363224cb68ad'),
#   'id': 'magic+gamma+telescope',
#   'url': 'https://archive.ics.uci.edu/dataset/159/magic+gamma+telescope',
#   'Title': 'MAGIC Gamma Telescope',
#   'Description': ' Data are MC generated to simulate registration of high energy gamma particles in an atmospheric Cherenkov telescope',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '19020',
#   '# Attributes': '11'},
#  {'_id': ObjectId('64bb7cb6bc23363224cb68ae'),
#   'id': 'speaker+accent+recognition',
#   'url': 'https://archive.ics.uci.edu/dataset/518/speaker+accent+recognition',
#   'Title': 'Speaker Accent Recognition',
#   'Description': ' Data set featuring single English words read by speakers from six different countries for accent detection and recognition',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Social',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '329',
#   '# Attributes': '12'},
#  {'_id': ObjectId('64bb7cb6bc23363224cb68af'),
#   'id': 'physical+therapy+exercises+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/730/physical+therapy+exercises+dataset',
#   'Title': 'Physical Therapy Exercises Dataset',
#   'Description': ' This dataset contains wearable inertial and magnetic sensor data during the execution of physical therapy exercises. There are eight types of physical therapy exercises, each of which has three execution types (correct, fast, and low-amplitude). Each execution type of each type of exercise was performed multiple times by five subjects. The subjects wore five MTx sensor units manufactured by XSens. Each unit contains three tri-axial sensors: an accelerometer, a gyroscope, and a magnetometer, sampled at 25 Hz.',
#   'Dataset Characteristics': 'Time-Series',
#   'Subject Area': 'Engineering',
#   'Associated Tasks': 'Classification, Clustering, Other',
#   'Attribute Type': '-',
#   '# Instances': '268881',
#   '# Attributes': '-'},
#  {'_id': ObjectId('64bb7cb6bc23363224cb68b0'),
#   'id': 'amazon+access+samples',
#   'url': 'https://archive.ics.uci.edu/dataset/216/amazon+access+samples',
#   'Title': 'Amazon Access Samples',
#   'Description': " Amazon's InfoSec is getting smarter about the way Access data is leveraged. This is an anonymized sample of access provisioned within the company.",
#   'Dataset Characteristics': 'Time-Series, Domain-Theory',
#   'Subject Area': 'Business',
#   'Associated Tasks': 'Regression, Clustering, Causal-Discovery',
#   'Attribute Type': '-',
#   '# Instances': '30000',
#   '# Attributes': '20000'},
#  {'_id': ObjectId('64bb7cb6bc23363224cb68b1'),
#   'id': 'higgs',
#   'url': 'https://archive.ics.uci.edu/dataset/280/higgs',
#   'Title': 'HIGGS',
#   'Description': ' This is a classification problem to distinguish between a signal process which produces Higgs bosons and a background process which does not. ',
#   'Dataset Characteristics': '-',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '11000000',
#   '# Attributes': '28'},
#  {'_id': ObjectId('64bb7cb7bc23363224cb68b2'),
#   'id': 'caesarian+section+classification+dataset',
#   'url': 'https://archive.ics.uci.edu/dataset/472/caesarian+section+classification+dataset',
#   'Title': 'Caesarian Section Classification Dataset',
#   'Description': ' This dataset contains information about caesarian section results of  80 pregnant women with the most important characteristics of delivery problems in the medical field.',
#   'Dataset Characteristics': 'Univariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Integer',
#   '# Instances': '80',
#   '# Attributes': '5'},
#  {'_id': ObjectId('64bb7cb7bc23363224cb68b3'),
#   'id': 'online+retail',
#   'url': 'https://archive.ics.uci.edu/dataset/352/online+retail',
#   'Title': 'Online Retail',
#   'Description': ' This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.',
#   'Dataset Characteristics': 'Multivariate, Sequential, Time-Series',
#   'Subject Area': 'Business',
#   'Associated Tasks': 'Classification, Clustering',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '541909',
#   '# Attributes': '8'},
#  {'_id': ObjectId('64bb7cb7bc23363224cb68b4'),
#   'id': 'autism+screening+adult',
#   'url': 'https://archive.ics.uci.edu/dataset/426/autism+screening+adult',
#   'Title': 'Autism Screening Adult',
#   'Description': ' Autistic Spectrum Disorder Screening Data for Adult. This dataset is related to classification and predictive tasks.',
#   'Dataset Characteristics': '-',
#   'Subject Area': 'Social',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Integer',
#   '# Instances': '704',
#   '# Attributes': '21'},
#  {'_id': ObjectId('64bb7cb7bc23363224cb68b5'),
#   'id': 'pems+sf',
#   'url': 'https://archive.ics.uci.edu/dataset/204/pems+sf',
#   'Title': 'PEMS-SF',
#   'Description': ' 15 months worth of daily data (440 daily records) that describes the occupancy rate, between 0 and 1, of different car lanes of the San Francisco bay area freeways across time.',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '440',
#   '# Attributes': '138672'},
#  {'_id': ObjectId('64bb7cb7bc23363224cb68b6'),
#   'id': 'vicon+physical+action+data+set',
#   'url': 'https://archive.ics.uci.edu/dataset/214/vicon+physical+action+data+set',
#   'Title': 'Vicon Physical Action Data Set',
#   'Description': ' The Physical Action Data Set includes 10 normal and 10 aggressive physical actions that measure the human activity. The data have been collected by 10 subjects using the Vicon 3D tracker.',
#   'Dataset Characteristics': 'Time-Series',
#   'Subject Area': 'Physical',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '3000',
#   '# Attributes': '27'},
#  {'_id': ObjectId('64bb7cb7bc23363224cb68b7'),
#   'id': 'scadi',
#   'url': 'https://archive.ics.uci.edu/dataset/446/scadi',
#   'Title': 'SCADI',
#   'Description': ' First self-care activities dataset based on ICF-CY.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification, Clustering',
#   'Attribute Type': '-',
#   '# Instances': '70',
#   '# Attributes': '206'},
#  {'_id': ObjectId('64bb7cb7bc23363224cb68b8'),
#   'id': 'led+display+domain',
#   'url': 'https://archive.ics.uci.edu/dataset/57/led+display+domain',
#   'Title': 'LED Display Domain',
#   'Description': ' From Classification and Regression Trees book; We provide here 2 C programs for generating sample databases',
#   'Dataset Characteristics': 'Multivariate, Data-Generator',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Categorical',
#   '# Instances': '-',
#   '# Attributes': '7'},
#  {'_id': ObjectId('64bb85e0bc23363224cb68bb'),
#   'id': 'stock+keeping+units',
#   'url': 'https://archive.ics.uci.edu/dataset/585/stock+keeping+units',
#   'Title': 'Stock keeping units',
#   'Description': ' The dataset is provided by the Ã¢â\x82¬Å\x93Trialto Latvia LTDÃ¢â\x82¬Â\x9d, the third-party logistics operator. Each observation stands for a distinct type of item for sale. ',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Business',
#   'Associated Tasks': 'Clustering',
#   'Attribute Type': 'Integer, Real',
#   '# Instances': '2279',
#   '# Attributes': '9'},
#  {'_id': ObjectId('64bb85e0bc23363224cb68bc'),
#   'id': 'lastfm+asia+social+network',
#   'url': 'https://archive.ics.uci.edu/dataset/595/lastfm+asia+social+network',
#   'Title': 'LastFM Asia Social Network',
#   'Description': ' A social network of LastFM users from Asian countries. The related task is predicting the country of origin based on social relations and artists liked.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Social',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': '-',
#   '# Instances': '7624',
#   '# Attributes': '7842'},
#  {'_id': ObjectId('64bb85e9bc23363224cb68bd'),
#   'id': 'wave+energy+converters',
#   'url': 'https://archive.ics.uci.edu/dataset/534/wave+energy+converters',
#   'Title': 'Wave Energy Converters',
#   'Description': ' This data set consists of positions and absorbed power outputs of wave energy converters (WECs) in four real wave scenarios from the southern coast of Australia. ',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '288000',
#   '# Attributes': '49'},
#  {'_id': ObjectId('64bb85ebbc23363224cb68be'),
#   'id': 'bar+crawl+detecting+heavy+drinking',
#   'url': 'https://archive.ics.uci.edu/dataset/559/bar+crawl+detecting+heavy+drinking',
#   'Title': 'Bar Crawl: Detecting Heavy Drinking',
#   'Description': ' Accelerometer and transdermal alcohol content data from a college bar crawl. Used to predict heavy drinking episodes via mobile data.',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification, Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '14057567',
#   '# Attributes': '3'},
#  {'_id': ObjectId('64bb85efbc23363224cb68bf'),
#   'id': 'divorce+predictors+data+set',
#   'url': 'https://archive.ics.uci.edu/dataset/497/divorce+predictors+data+set',
#   'Title': 'Divorce Predictors data set',
#   'Description': ' Participants completed the Personal Information Form and Divorce Predictors Scale. ',
#   'Dataset Characteristics': 'Multivariate, Univariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Integer',
#   '# Instances': '170',
#   '# Attributes': '54'},
#  {'_id': ObjectId('64bb85f9bc23363224cb68c0'),
#   'id': 'shoulder+implant+x+ray+manufacturer+classification',
#   'url': 'https://archive.ics.uci.edu/dataset/517/shoulder+implant+x+ray+manufacturer+classification',
#   'Title': 'Shoulder Implant X-Ray Manufacturer Classification',
#   'Description': ' 597 de-identified raw X-ray scans of implanted shoulder prostheses from four manufactures.',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification',
#   'Attribute Type': 'Real',
#   '# Instances': '597',
#   '# Attributes': '1'},
#  {'_id': ObjectId('64bb85fabc23363224cb68c1'),
#   'id': 'exasens',
#   'url': 'https://archive.ics.uci.edu/dataset/523/exasens',
#   'Title': 'Exasens',
#   'Description': ' This repository introduces a novel dataset for the classification of 4 groups of respiratory diseases: Chronic Obstructive Pulmonary Disease (COPD), asthma, infected, and Healthy Controls (HC).',
#   'Dataset Characteristics': 'Multivariate',
#   'Subject Area': 'Life',
#   'Associated Tasks': 'Classification, Clustering',
#   'Attribute Type': 'Integer',
#   '# Instances': '399',
#   '# Attributes': '4'},
#  {'_id': ObjectId('64bb85fcbc23363224cb68c2'),
#   'id': 'air+quality',
#   'url': 'https://archive.ics.uci.edu/dataset/360/air+quality',
#   'Title': 'Air Quality',
#   'Description': ' Contains the responses of a gas multisensor device deployed on the field in an Italian city. Hourly responses averages are recorded along with gas concentrations references from a certified analyzer. ',
#   'Dataset Characteristics': 'Multivariate, Time-Series',
#   'Subject Area': 'Computer',
#   'Associated Tasks': 'Regression',
#   'Attribute Type': 'Real',
#   '# Instances': '9358',
#   '# Attributes': '15'}]

# %%
collection.count_documents({})
# Out:
# 624

# %%
files[0].keys()
# Out:
# dict_keys(['_id', 'id', 'url', 'Title', 'Description', 'Dataset Characteristics', 'Subject Area', 'Associated Tasks', 'Attribute Type', '# Instances', '# Attributes'])

# %% [markdown]
# ## Convert files to `Ducument` type
#
# 'Document' must be defined in the fashion same as the data type returns by WebBaseLoader from langchain,
#
# where 'metadata' must include key 'source', 'title', 'description', and 'language' (all in lower case),
#
# still figuring out a way to make it more flexible

# %%
from collections import namedtuple

Document = namedtuple("Document", ["page_content", "metadata"])
docs = [
    Document(file['Description'], {"Subject Area": file['Subject Area'], "title": file['Title'], "source": file['url'], "description": file['Description'], "language": "en"})
    for file in files
]

# %%
docs[0].page_content
# Out:
# ' Dataset is well suited for segmentation tasks. It contains 101 scanned pages from different newspapers and magazines in Russian with ground truth pixel-based masks.'

# %% [markdown]
# ## Split texts

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=1024, chunk_overlap=0)
docs_split = text_splitter.split_documents(docs)

# %%
docs_split
# Out:
# [Document(page_content='Dataset is well suited for segmentation tasks. It contains 101 scanned pages from different newspapers and magazines in Russian with ground truth pixel-based masks.', metadata={'Subject Area': 'Computer', 'title': 'Newspaper and magazine images segmentation dataset', 'source': 'https://archive.ics.uci.edu/dataset/306/newspaper+and+magazine+images+segmentation+dataset', 'description': ' Dataset is well suited for segmentation tasks. It contains 101 scanned pages from different newspapers and magazines in Russian with ground truth pixel-based masks.', 'language': 'en'}),
#  Document(page_content="A total of 3810 rice grain's images were taken for the two species, processed and feature inferences were made. 7 morphological features were obtained for each grain of rice.", metadata={'Subject Area': 'Computer', 'title': 'Rice (Cammeo and Osmancik)', 'source': 'https://archive.ics.uci.edu/dataset/545/rice+cammeo+and+osmancik', 'description': " A total of 3810 rice grain's images were taken for the two species, processed and feature inferences were made. 7 morphological features were obtained for each grain of rice.", 'language': 'en'}),
#  Document(page_content='A multisource and multivariate dataset for indoor localisation methods based on WLAN and Geo-Magnetic Ã¯Â¬Â\x81eld Ã¯Â¬Â\x81ngerprinting', metadata={'Subject Area': 'Computer', 'title': 'Geo-Magnetic field and WLAN dataset for indoor localisation from wristband and smartphone', 'source': 'https://archive.ics.uci.edu/dataset/377/geo+magnetic+field+and+wlan+dataset+for+indoor+localisation+from+wristband+and+smartphone', 'description': ' A multisource and multivariate dataset for indoor localisation methods based on WLAN and Geo-Magnetic Ã¯Â¬Â\x81eld Ã¯Â¬Â\x81ngerprinting', 'language': 'en'}),
#  Document(page_content='The data set contains the recordings of 16 chemical sensors exposed to two dynamic gas mixtures at varying concentrations. For each mixture, signals were acquired continuously during 12 hours.', metadata={'Subject Area': 'Computer', 'title': 'Gas sensor array under dynamic gas mixtures', 'source': 'https://archive.ics.uci.edu/dataset/322/gas+sensor+array+under+dynamic+gas+mixtures', 'description': ' The data set contains the recordings of 16 chemical sensors exposed to two dynamic gas mixtures at varying concentrations. For each mixture, signals were acquired continuously during 12 hours.', 'language': 'en'}),
#  Document(page_content='This data set contains a list of over 10000 films including many older, odd, and cult films. There is information on actors, casts, directors, producers, studios, etc.', metadata={'Subject Area': 'Other', 'title': 'Movie', 'source': 'https://archive.ics.uci.edu/dataset/132/movie', 'description': ' This data set contains a list of over 10000 films including many older, odd, and cult films. There is information on actors, casts, directors, producers, studios, etc.', 'language': 'en'}),
#  Document(page_content="The dataset is about the users' learning activities and knowledge levels on subjects of DC  Electrical Machines. The dataset had been obtained from online web-courses  and reported in my Ph.D. Thesis.", metadata={'Subject Area': 'Computer', 'title': "ser Knowledge Modeling Data (Students' Knowledge Levels on DC Electrical Machines)", 'source': 'https://archive.ics.uci.edu/dataset/263/ser+knowledge+modeling+data+students+knowledge+levels+on+dc+electrical+machines', 'description': " The dataset is about the users' learning activities and knowledge levels on subjects of DC  Electrical Machines. The dataset had been obtained from online web-courses  and reported in my Ph.D. Thesis.", 'language': 'en'}),
#  Document(page_content='Persian questions gathered from a jeopardy game broadcasted on Iranian national television.', metadata={'Subject Area': 'Other', 'title': 'University of Tehran Question Dataset 2016 (UTQD.2016)', 'source': 'https://archive.ics.uci.edu/dataset/425/university+of+tehran+question+dataset+2016+utqd+2016', 'description': ' Persian questions gathered from a jeopardy game broadcasted on Iranian national television. ', 'language': 'en'}),
#  Document(page_content='The task is to train a network to discriminate between sonar signals bounced off a metal cylinder and those bounced off a roughly cylindrical rock.', metadata={'Subject Area': 'Physical', 'title': 'Connectionist Bench (Sonar, Mines vs. Rocks)', 'source': 'https://archive.ics.uci.edu/dataset/151/connectionist+bench+sonar+mines+vs+rocks', 'description': ' The task is to train a network to discriminate between sonar signals bounced off a metal cylinder and those bounced off a roughly cylindrical rock.', 'language': 'en'}),
#  Document(page_content='BAUM-1 dataset contains 1184 multimodal facial video clips collected from 31 subjects. The 1184 video clips contain spontaneous facial expressions and speech of 13 emotional and mental states.', metadata={'Subject Area': 'Computer', 'title': 'BAUM-1', 'source': 'https://archive.ics.uci.edu/dataset/473/baum+1', 'description': ' BAUM-1 dataset contains 1184 multimodal facial video clips collected from 31 subjects. The 1184 video clips contain spontaneous facial expressions and speech of 13 emotional and mental states.', 'language': 'en'}),
#  Document(page_content='PANDOR is a novel and publicly available dataset for online recommendation provided by Purch (http://www.purch.com/).', metadata={'Subject Area': 'Life', 'title': 'PANDOR', 'source': 'https://archive.ics.uci.edu/dataset/460/pandor', 'description': ' PANDOR is a novel and publicly available dataset for online recommendation provided by Purch (http://www.purch.com/). ', 'language': 'en'}),
#  Document(page_content='Corpus intended to do cleaning (or binarization) and enhancement of noisy grayscale printed text images using supervised learning methods. Noisy images and their corresponding ground truth provided.', metadata={'Subject Area': 'Computer', 'title': 'NoisyOffice', 'source': 'https://archive.ics.uci.edu/dataset/318/noisyoffice', 'description': ' Corpus intended to do cleaning (or binarization) and enhancement of noisy grayscale printed text images using supervised learning methods. Noisy images and their corresponding ground truth provided.', 'language': 'en'}),
#  Document(page_content='This study looked into assessing the heating load and cooling load requirements of buildings (that is, energy efficiency) as a function of building parameters.', metadata={'Subject Area': 'Computer', 'title': 'Energy efficiency', 'source': 'https://archive.ics.uci.edu/dataset/242/energy+efficiency', 'description': ' This study looked into assessing the heating load and cooling load requirements of buildings (that is, energy efficiency) as a function of building parameters.', 'language': 'en'}),
#  Document(page_content='The dataset is about bankruptcy prediction of Polish companies.The bankrupt companies were analyzed in the period 2000-2012, while the still operating companies were evaluated from 2007 to 2013.', metadata={'Subject Area': 'Business', 'title': 'Polish companies bankruptcy data', 'source': 'https://archive.ics.uci.edu/dataset/365/polish+companies+bankruptcy+data', 'description': ' The dataset is about bankruptcy prediction of Polish companies.The bankrupt companies were analyzed in the period 2000-2012, while the still operating companies were evaluated from 2007 to 2013.', 'language': 'en'}),
#  Document(page_content='A multilingual audio-visual affective face database consisting of 1047 video clips of 286 subjects.', metadata={'Subject Area': 'Computer', 'title': 'BAUM-2', 'source': 'https://archive.ics.uci.edu/dataset/474/baum+2', 'description': ' A multilingual audio-visual affective face database consisting of 1047 video clips of 286 subjects. ', 'language': 'en'}),
#  Document(page_content='Primate splice-junction gene sequences (DNA) with associated imperfect domain theory', metadata={'Subject Area': 'Life', 'title': 'Molecular Biology (Splice-junction Gene Sequences)', 'source': 'https://archive.ics.uci.edu/dataset/69/molecular+biology+splice+junction+gene+sequences', 'description': ' Primate splice-junction gene sequences (DNA) with associated imperfect domain theory', 'language': 'en'}),
#  Document(page_content='This dataset represents a set of possible advertisements on Internet pages.', metadata={'Subject Area': 'Computer', 'title': 'Internet Advertisements', 'source': 'https://archive.ics.uci.edu/dataset/51/internet+advertisements', 'description': ' This dataset represents a set of possible advertisements on Internet pages.', 'language': 'en'}),
#  Document(page_content='Roman Urdu (the scripting style for Urdu language) is one of the limited resource languages.A data corpus comprising of more than 20000 records was collected.', metadata={'Subject Area': 'Computer', 'title': 'Roman Urdu Data Set', 'source': 'https://archive.ics.uci.edu/dataset/458/roman+urdu+data+set', 'description': ' Roman Urdu (the scripting style for Urdu language) is one of the limited resource languages.A data corpus comprising of more than 20000 records was collected.', 'language': 'en'}),
#  Document(page_content='The JARtool project was a pioneering effort to develop an automatic system for cataloging small volcanoes in the large set of Venus images returned by the Magellan spacecraft.', metadata={'Subject Area': 'Physical', 'title': 'Volcanoes on Venus - JARtool experiment', 'source': 'https://archive.ics.uci.edu/dataset/142/volcanoes+on+venus+jartool+experiment', 'description': ' The JARtool project was a pioneering effort to develop an automatic system for cataloging small volcanoes in the large set of Venus images returned by the Magellan spacecraft.', 'language': 'en'}),
#  Document(page_content='Recordings of 16 volunteers performing 14 Activities of Daily Living (ADL) while carrying a single wrist-worn tri-axial accelerometer.', metadata={'Subject Area': 'Computer', 'title': 'Dataset for ADL Recognition with Wrist-worn Accelerometer', 'source': 'https://archive.ics.uci.edu/dataset/283/dataset+for+adl+recognition+with+wrist+worn+accelerometer', 'description': ' Recordings of 16 volunteers performing 14 Activities of Daily Living (ADL) while carrying a single wrist-worn tri-axial accelerometer.', 'language': 'en'}),
#  Document(page_content='Relative CPU Performance Data, described in terms of its cycle time, memory size, etc.', metadata={'Subject Area': 'Computer', 'title': 'Computer Hardware', 'source': 'https://archive.ics.uci.edu/dataset/29/computer+hardware', 'description': ' Relative CPU Performance Data, described in terms of its cycle time, memory size, etc.', 'language': 'en'}),
#  Document(page_content='Detection of mines buried in the ground is very important in terms of safety of life and property. Many different methods have been used in this regard; however, it has not yet been possible to achieve 100% success. Mine detection process consists of sensor design, data analysis and decision algorithm phases. The magnetic anomaly method works according to the principle of measuring the anomalies resulting from the object in the magnetic field that disturbs the structure of it, the magnetic field, and the data obtained at this point are used to determine the conditions such as motion and position. The determination of parameters such as position, depth or direction of motion using magnetic anomaly has been carried out since 1970.', metadata={'Subject Area': 'Engineering', 'title': 'Land Mines', 'source': 'https://archive.ics.uci.edu/dataset/763/land+mines-1', 'description': ' Detection of mines buried in the ground is very important in terms of safety of life and property. Many different methods have been used in this regard; however, it has not yet been possible to achieve 100% success. Mine detection process consists of sensor design, data analysis and decision algorithm phases. The magnetic anomaly method works according to the principle of measuring the anomalies resulting from the object in the magnetic field that disturbs the structure of it, the magnetic field, and the data obtained at this point are used to determine the conditions such as motion and position. The determination of parameters such as position, depth or direction of motion using magnetic anomaly has been carried out since 1970.', 'language': 'en'}),
#  Document(page_content='Contains accelerometer and gyroscope time-series sensor data collected from a smartphone and smartwatch as 51 test subjects perform 18 activities for 3 minutes each.', metadata={'Subject Area': 'Computer', 'title': 'WISDM Smartphone and Smartwatch Activity and Biometrics Dataset ', 'source': 'https://archive.ics.uci.edu/dataset/507/wisdm+smartphone+and+smartwatch+activity+and+biometrics+dataset', 'description': ' Contains accelerometer and gyroscope time-series sensor data collected from a smartphone and smartwatch as 51 test subjects perform 18 activities for 3 minutes each. ', 'language': 'en'}),
#  Document(page_content='The dataset is provided by the Ã¢â\x82¬Å\x93Trialto Latvia LTDÃ¢â\x82¬Â\x9d, the third-party logistics operator. Each observation stands for a distinct type of item for sale.', metadata={'Subject Area': 'Business', 'title': 'Stock keeping units', 'source': 'https://archive.ics.uci.edu/dataset/531/stock+keeping+units', 'description': ' The dataset is provided by the Ã¢â\x82¬Å\x93Trialto Latvia LTDÃ¢â\x82¬Â\x9d, the third-party logistics operator. Each observation stands for a distinct type of item for sale. ', 'language': 'en'}),
#  Document(page_content='3 different exercises: sitting, standing and walking in the muscles: biceps femoris, vastus medialis, rectus femoris and semitendinosus addition to goniometry in the exercises.', metadata={'Subject Area': 'Computer', 'title': 'EMG dataset in Lower Limb', 'source': 'https://archive.ics.uci.edu/dataset/278/emg+dataset+in+lower+limb', 'description': ' 3 different exercises: sitting, standing and walking in the muscles: biceps femoris, vastus medialis, rectus femoris and semitendinosus addition to goniometry in the exercises.', 'language': 'en'}),
#  Document(page_content='Little Documentation', metadata={'Subject Area': 'Physical', 'title': 'Cloud', 'source': 'https://archive.ics.uci.edu/dataset/155/cloud', 'description': ' Little Documentation', 'language': 'en'}),
#  Document(page_content="This dataset was collected by Shan-Hung Wu and DataLab members at NTHU, Taiwan. There're 325 user-perceived clusters from 100 users and their corresponding descriptions.", metadata={'Subject Area': 'Computer', 'title': 'Mturk User-Perceived Clusters over Images', 'source': 'https://archive.ics.uci.edu/dataset/416/mturk+user+perceived+clusters+over+images', 'description': " This dataset was collected by Shan-Hung Wu and DataLab members at NTHU, Taiwan. There're 325 user-perceived clusters from 100 users and their corresponding descriptions.", 'language': 'en'}),
#  Document(page_content='Classification of radar returns from the ionosphere', metadata={'Subject Area': 'Physical', 'title': 'Ionosphere', 'source': 'https://archive.ics.uci.edu/dataset/52/ionosphere', 'description': ' Classification of radar returns from the ionosphere', 'language': 'en'}),
#  Document(page_content='This data consists of odors of 20 different perfumes. Data was obtained by using a handheld odor meter (OMX-GR sensor) per second for 28 seconds period.', metadata={'Subject Area': 'Computer', 'title': 'Perfume Data', 'source': 'https://archive.ics.uci.edu/dataset/303/perfume+data', 'description': ' This data consists of odors of 20 different perfumes. Data was obtained by using a handheld odor meter (OMX-GR sensor) per second for 28 seconds period.', 'language': 'en'}),
#  Document(page_content='This data arises from a large study to examine EEG correlates of genetic predisposition to alcoholism. It contains measurements from 64 electrodes placed on the scalp sampled at 256 Hz', metadata={'Subject Area': 'Life', 'title': 'EEG Database', 'source': 'https://archive.ics.uci.edu/dataset/121/eeg+database', 'description': ' This data arises from a large study to examine EEG correlates of genetic predisposition to alcoholism. It contains measurements from 64 electrodes placed on the scalp sampled at 256 Hz', 'language': 'en'}),
#  Document(page_content='3D road network with highly accurate elevation information (+-20cm) from Denmark used in eco-routing and fuel/Co2-estimation routing algorithms.', metadata={'Subject Area': 'Computer', 'title': '3D Road Network (North Jutland, Denmark)', 'source': 'https://archive.ics.uci.edu/dataset/246/3d+road+network+north+jutland+denmark', 'description': ' 3D road network with highly accurate elevation information (+-20cm) from Denmark used in eco-routing and fuel/Co2-estimation routing algorithms.', 'language': 'en'}),
#  Document(page_content='Measurements of morphological descriptors  of wheat kernels from Punjab State. A machine Learning based technique was used to extract 15 features, all are real valued attributes', metadata={'Subject Area': 'Computer', 'title': 'Wheat kernels', 'source': 'https://archive.ics.uci.edu/dataset/596/wheat+kernels', 'description': ' Measurements of morphological descriptors  of wheat kernels from Punjab State. A machine Learning based technique was used to extract 15 features, all are real valued attributes', 'language': 'en'}),
#  Document(page_content='MesotheliomaÃ¢â\x82¬â\x84¢s disease data set were prepared at Dicle University Faculty of Medicine in Turkey.\nThree hundred and twenty-four Mesothelioma patient data. In the dataset, all samples have 34 features.', metadata={'Subject Area': 'Computer', 'title': 'MesotheliomaÃ¢â\x82¬â\x84¢s disease data set ', 'source': 'https://archive.ics.uci.edu/dataset/351/mesothelioma+s+disease+data+set', 'description': ' MesotheliomaÃ¢â\x82¬â\x84¢s disease data set were prepared at Dicle University Faculty of Medicine in Turkey.\nThree hundred and twenty-four Mesothelioma patient data. In the dataset, all samples have 34 features.', 'language': 'en'}),
#  Document(page_content="Running times for multiplying two 2048 x 2048 matrices using a GPU OpenCL SGEMM kernel with varying parameters (using the library 'CLTune').", metadata={'Subject Area': 'Computer', 'title': 'SGEMM GPU kernel performance', 'source': 'https://archive.ics.uci.edu/dataset/440/sgemm+gpu+kernel+performance', 'description': " Running times for multiplying two 2048 x 2048 matrices using a GPU OpenCL SGEMM kernel with varying parameters (using the library 'CLTune').", 'language': 'en'}),
#  Document(page_content='This dataset includes quantitative and categorical features from online reviews from 21 hotels located in Las Vegas Strip, extracted from TripAdvisor (http://www.tripadvisor.com).', metadata={'Subject Area': 'Business', 'title': 'Las Vegas Strip', 'source': 'https://archive.ics.uci.edu/dataset/397/las+vegas+strip', 'description': ' This dataset includes quantitative and categorical features from online reviews from 21 hotels located in Las Vegas Strip, extracted from TripAdvisor (http://www.tripadvisor.com).', 'language': 'en'}),
#  Document(page_content="The sEMG for Basic Hand movements includes 2 databases of surface electromyographic signals of 6 hand movements using Delsys' EMG System. Healthy subjects conducted six daily life grasps.", metadata={'Subject Area': 'Life', 'title': 'sEMG for Basic Hand movements', 'source': 'https://archive.ics.uci.edu/dataset/313/semg+for+basic+hand+movements', 'description': " The sEMG for Basic Hand movements includes 2 databases of surface electromyographic signals of 6 hand movements using Delsys' EMG System. Healthy subjects conducted six daily life grasps.", 'language': 'en'}),
#  Document(page_content='The MEx Multi-modal Exercise dataset contains data of 7 different\nphysiotherapy exercises, performed by 30 subjects recorded with 2 accelerometers,\na pressure mat and a depth camera.', metadata={'Subject Area': 'Computer', 'title': 'MEx', 'source': 'https://archive.ics.uci.edu/dataset/500/mex', 'description': ' The MEx Multi-modal Exercise dataset contains data of 7 different\nphysiotherapy exercises, performed by 30 subjects recorded with 2 accelerometers,\na pressure mat and a depth camera.', 'language': 'en'}),
#  Document(page_content='Contains Wikipedia pages about popular mathematics topics and the edges describe the links from one page to another. Features describe the number of daily visits between 2019 and 2021 March.', metadata={'Subject Area': 'Social', 'title': 'Wikipedia Math Essentials', 'source': 'https://archive.ics.uci.edu/dataset/605/wikipedia+math+essentials', 'description': ' Contains Wikipedia pages about popular mathematics topics and the edges describe the links from one page to another. Features describe the number of daily visits between 2019 and 2021 March.', 'language': 'en'}),
#  Document(page_content='Nominal audiology dataset from Baylor', metadata={'Subject Area': 'Life', 'title': 'Audiology (Original)', 'source': 'https://archive.ics.uci.edu/dataset/7/audiology+original', 'description': ' Nominal audiology dataset from Baylor', 'language': 'en'}),
#  Document(page_content='This dataset contains the dynamic features of 107,888 executables, collected by VirusShare from Nov/2010 to Jul/2014.', metadata={'Subject Area': 'Computer', 'title': 'Dynamic Features of VirusShare Executables', 'source': 'https://archive.ics.uci.edu/dataset/413/dynamic+features+of+virusshare+executables', 'description': ' This dataset contains the dynamic features of 107,888 executables, collected by VirusShare from Nov/2010 to Jul/2014.', 'language': 'en'}),
#  Document(page_content='Dataset of patient features', metadata={'Subject Area': 'Life', 'title': 'Post-Operative Patient', 'source': 'https://archive.ics.uci.edu/dataset/82/post+operative+patient', 'description': ' Dataset of patient features', 'language': 'en'}),
#  Document(page_content='Classify ceramic samples based on their chemical composition from energy dispersive X-ray fluorescence', metadata={'Subject Area': 'Physical', 'title': 'Chemical Composition of Ceramic Samples', 'source': 'https://archive.ics.uci.edu/dataset/583/chemical+composition+of+ceramic+samples', 'description': ' Classify ceramic samples based on their chemical composition from energy dispersive X-ray fluorescence', 'language': 'en'}),
#  Document(page_content='The handwritten dataset was collected from 170 participants with a total of 5,180 numeral patterns. The dataset is named Prince Mohammad Bin Fahd University - Urdu/Arabic Database (PMU-UD).', metadata={'Subject Area': 'Computer', 'title': 'PMU-UD', 'source': 'https://archive.ics.uci.edu/dataset/469/pmu+ud', 'description': ' The handwritten dataset was collected from 170 participants with a total of 5,180 numeral patterns. The dataset is named Prince Mohammad Bin Fahd University - Urdu/Arabic Database (PMU-UD). ', 'language': 'en'}),
#  Document(page_content='The file animals.c is a data generator of structured instances representing quadruped animals', metadata={'Subject Area': 'Life', 'title': 'Quadruped Mammals', 'source': 'https://archive.ics.uci.edu/dataset/86/quadruped+mammals', 'description': '  The file animals.c is a data generator of structured instances representing quadruped animals', 'language': 'en'}),
#  Document(page_content='data collected on 2022, in King Saud University in riyadh for recognizing human activities using mobile phone IMU sensors (Accelerometer, and Gyroscope). these activity is calssified to standing(stop), or walking.', metadata={'Subject Area': 'Computer Science', 'title': 'accelerometer_gyro_mobile_phone_dataset', 'source': 'https://archive.ics.uci.edu/dataset/755/accelerometer+gyro+mobile+phone+dataset', 'description': ' data collected on 2022, in King Saud University in riyadh for recognizing human activities using mobile phone IMU sensors (Accelerometer, and Gyroscope). these activity is calssified to standing(stop), or walking.', 'language': 'en'}),
#  Document(page_content='Prediction of myocardial infarction complications', metadata={'Subject Area': 'Life', 'title': 'Myocardial infarction complications', 'source': 'https://archive.ics.uci.edu/dataset/579/myocardial+infarction+complications', 'description': ' Prediction of myocardial infarction complications', 'language': 'en'}),
#  Document(page_content='Domain Theory on Economic Sanctions; Undocumented', metadata={'Subject Area': 'Financial', 'title': 'Economic Sanctions', 'source': 'https://archive.ics.uci.edu/dataset/153/economic+sanctions', 'description': ' Domain Theory on Economic Sanctions; Undocumented', 'language': 'en'}),
#  Document(page_content='Two sets of datasets are given: pyrimidines and triazines', metadata={'Subject Area': 'Physical', 'title': 'Qualitative Structure Activity Relationships', 'source': 'https://archive.ics.uci.edu/dataset/85/qualitative+structure+activity+relationships', 'description': ' Two sets of datasets are given: pyrimidines and triazines', 'language': 'en'}),
#  Document(page_content='The IM-AccGyro dataset is devised to benchmark techniques dealing with human activity recognition based on inertial sensors.', metadata={'Subject Area': 'Physical', 'title': 'Intelligent Media Accelerometer and Gyroscope (IM-AccGyro) Dataset', 'source': 'https://archive.ics.uci.edu/dataset/578/intelligent+media+accelerometer+and+gyroscope+im+accgyro+dataset', 'description': ' The IM-AccGyro dataset is devised to benchmark techniques dealing with human activity recognition based on inertial sensors. \n\t', 'language': 'en'}),
#  Document(page_content='The data set addresses the condition assessment of a hydraulic test rig based on multi sensor data. Four fault types are superimposed with several severity grades impeding selective quantification.', metadata={'Subject Area': 'Computer', 'title': 'Condition monitoring of hydraulic systems', 'source': 'https://archive.ics.uci.edu/dataset/447/condition+monitoring+of+hydraulic+systems', 'description': ' The data set addresses the condition assessment of a hydraulic test rig based on multi sensor data. Four fault types are superimposed with several severity grades impeding selective quantification.', 'language': 'en'}),
#  Document(page_content='Instances in this dataset contain features extracted from facebook posts. The task associated with the data is to predict how many comments the post will receive.', metadata={'Subject Area': 'Other', 'title': 'Facebook Comment Volume Dataset', 'source': 'https://archive.ics.uci.edu/dataset/363/facebook+comment+volume+dataset', 'description': ' Instances in this dataset contain features extracted from facebook posts. The task associated with the data is to predict how many comments the post will receive.', 'language': 'en'}),
#  Document(page_content='This Data set provides preprocessed and cleaned vital signals which can be used in designing algorithms for cuff-less estimation of the blood pressure.', metadata={'Subject Area': 'Life', 'title': 'Cuff-Less Blood Pressure Estimation', 'source': 'https://archive.ics.uci.edu/dataset/340/cuff+less+blood+pressure+estimation', 'description': ' This Data set provides preprocessed and cleaned vital signals which can be used in designing algorithms for cuff-less estimation of the blood pressure.', 'language': 'en'}),
#  Document(page_content='The goal is to model mutant p53 transcriptional activity (active vs inactive) based on data extracted from biophysical simulations.', metadata={'Subject Area': 'Life', 'title': 'p53 Mutants', 'source': 'https://archive.ics.uci.edu/dataset/188/p53+mutants', 'description': ' The goal is to model mutant p53 transcriptional activity (active vs inactive) based on data extracted from biophysical simulations.\n', 'language': 'en'}),
#  Document(page_content='This data consists of 640 black and white face images of people taken with varying pose (straight, left, right, up), expression (neutral, happy, sad, angry), eyes (wearing sunglasses or not), and size', metadata={'Subject Area': 'Other', 'title': 'CMU Face Images', 'source': 'https://archive.ics.uci.edu/dataset/124/cmu+face+images', 'description': ' This data consists of 640 black and white face images of people taken with varying pose (straight, left, right, up), expression (neutral, happy, sad, angry), eyes (wearing sunglasses or not), and size', 'language': 'en'}),
#  Document(page_content='20 falls and 16 daily living activities were performed by 17 volunteers with 5 repetitions while wearing 6 sensors (3.060 instances) that attached to their head, chest, waist, wrist, thigh and ankle.', metadata={'Subject Area': 'Life', 'title': 'Simulated Falls and Daily Living Activities Data Set', 'source': 'https://archive.ics.uci.edu/dataset/455/simulated+falls+and+daily+living+activities+data+set', 'description': ' 20 falls and 16 daily living activities were performed by 17 volunteers with 5 repetitions while wearing 6 sensors (3.060 instances) that attached to their head, chest, waist, wrist, thigh and ankle.', 'language': 'en'}),
#  Document(page_content='A dataset to explore machine learning approaches for the identification of microorganisms from mass-spectrometry data.', metadata={'Subject Area': 'Life', 'title': 'MicroMass', 'source': 'https://archive.ics.uci.edu/dataset/253/micromass', 'description': ' A dataset to explore machine learning approaches for the identification of microorganisms from mass-spectrometry data.', 'language': 'en'}),
#  Document(page_content='In SIFT10M, each data point is a SIFT feature which is extracted from Caltech-256 by the open source VLFeat library. The corresponding patches of the SIFT features are provided.', metadata={'Subject Area': 'Computer', 'title': 'SIFT10M', 'source': 'https://archive.ics.uci.edu/dataset/353/sift10m', 'description': ' In SIFT10M, each data point is a SIFT feature which is extracted from Caltech-256 by the open source VLFeat library. The corresponding patches of the SIFT features are provided.', 'language': 'en'}),
#  Document(page_content='This data describes the page visits of users who visited msnbc.com on September 28, 1999. Visits are recorded at the level of URL category (see description) and are recorded in time order.', metadata={'Subject Area': 'Computer', 'title': 'MSNBC.com Anonymous Web Data', 'source': 'https://archive.ics.uci.edu/dataset/133/msnbc+com+anonymous+web+data', 'description': ' This data describes the page visits of users who visited msnbc.com on September 28, 1999. Visits are recorded at the level of URL category (see description) and are recorded in time order.', 'language': 'en'}),
#  Document(page_content='High-resolution Remote Sensing data set (Quickbird). Small number of training samples of diseased trees, large number for other land cover. Testing data set from stratified random sample of image.', metadata={'Subject Area': 'Life', 'title': 'Wilt', 'source': 'https://archive.ics.uci.edu/dataset/285/wilt', 'description': ' High-resolution Remote Sensing data set (Quickbird). Small number of training samples of diseased trees, large number for other land cover. Testing data set from stratified random sample of image.', 'language': 'en'}),
#  Document(page_content='MicroblogPCU data is crawled from sina weibo microblog[http://weibo.com/]. This data can be used to study machine learning methods  as well as do some social network research.', metadata={'Subject Area': 'Computer', 'title': 'microblogPCU', 'source': 'https://archive.ics.uci.edu/dataset/323/microblogpcu', 'description': ' MicroblogPCU data is crawled from sina weibo microblog[http://weibo.com/]. This data can be used to study machine learning methods  as well as do some social network research. ', 'language': 'en'}),
#  Document(page_content='This data set used in the CoIL 2000 Challenge contains information on customers of an insurance company. The data consists of 86 variables and includes product usage data and socio-demographic data', metadata={'Subject Area': 'Social', 'title': 'Insurance Company Benchmark (COIL 2000)', 'source': 'https://archive.ics.uci.edu/dataset/125/insurance+company+benchmark+coil+2000', 'description': ' This data set used in the CoIL 2000 Challenge contains information on customers of an insurance company. The data consists of 86 variables and includes product usage data and socio-demographic data', 'language': 'en'}),
#  Document(page_content='The data here are the ZZAlphaÃ\x82Â® machine learning recommendations made for various US traded stock portfolios the morning of each day during the 3 year period Jan 1, 2012 - Dec 31, 2014.', metadata={'Subject Area': 'Business', 'title': 'Machine Learning based ZZAlpha Ltd. Stock Recommendations 2012-2014', 'source': 'https://archive.ics.uci.edu/dataset/337/machine+learning+based+zzalpha+ltd+stock+recommendations+2012+2014', 'description': ' The data here are the ZZAlphaÃ\x82Â® machine learning recommendations made for various US traded stock portfolios the morning of each day during the 3 year period Jan 1, 2012 - Dec 31, 2014.  ', 'language': 'en'}),
#  Document(page_content='The data set of performances of weighted scoring stock portfolios are obtained with mixture design from the US stock market historical database.', metadata={'Subject Area': 'Business', 'title': 'Stock portfolio performance', 'source': 'https://archive.ics.uci.edu/dataset/390/stock+portfolio+performance', 'description': ' The data set of performances of weighted scoring stock portfolios are obtained with mixture design from the US stock market historical database.', 'language': 'en'}),
#  Document(page_content='The objective is to determine the set of boolean rules that describe the interactions of the nodes within this plant signaling network.  The dataset includes 300 separate boolean pseudodynamic simulations using an asynchronous update scheme.', metadata={'Subject Area': 'Life', 'title': 'Abscisic Acid Signaling Network', 'source': 'https://archive.ics.uci.edu/dataset/173/abscisic+acid+signaling+network', 'description': ' The objective is to determine the set of boolean rules that describe the interactions of the nodes within this plant signaling network.  The dataset includes 300 separate boolean pseudodynamic simulations using an asynchronous update scheme. ', 'language': 'en'}),
#  Document(page_content='The data from Twitter was collected during 360 consecutive days. It was done by querying 1497 English keywords sampled from Wikipedia. This dataset is proposed in a Learning to rank setting.', metadata={'Subject Area': 'Computer', 'title': 'Predict keywords activities in a online social media', 'source': 'https://archive.ics.uci.edu/dataset/276/predict+keywords+activities+in+a+online+social+media', 'description': ' The data from Twitter was collected during 360 consecutive days. It was done by querying 1497 English keywords sampled from Wikipedia. This dataset is proposed in a Learning to rank setting.', 'language': 'en'}),
#  Document(page_content='Instances in this dataset contain features extracted from blog posts. The task associated with the data is to predict how many comments the post will receive.', metadata={'Subject Area': 'Social', 'title': 'BlogFeedback', 'source': 'https://archive.ics.uci.edu/dataset/304/blogfeedback', 'description': ' Instances in this dataset contain features extracted from blog posts. The task associated with the data is to predict how many comments the post will receive.', 'language': 'en'}),
#  Document(page_content='The dataset is a collection of text forum threads with class labels reflects the reply quality to the Initial-Post, 3 for complete relevant, 2 for partially relevant, and 1 for irrelevant', metadata={'Subject Area': 'Computer', 'title': 'Labeled Text Forum Threads Dataset', 'source': 'https://archive.ics.uci.edu/dataset/584/labeled+text+forum+threads+dataset', 'description': ' The dataset is a collection of text forum threads with class labels reflects the reply quality to the Initial-Post, 3 for complete relevant, 2 for partially relevant, and 1 for irrelevant', 'language': 'en'}),
#  Document(page_content='The shuttle dataset contains 9 attributes all of which are numerical. Approximately 80% of the data belongs to class 1', metadata={'Subject Area': 'Physical', 'title': 'Statlog (Shuttle)', 'source': 'https://archive.ics.uci.edu/dataset/148/statlog+shuttle', 'description': ' The shuttle dataset contains 9 attributes all of which are numerical. Approximately 80% of the data belongs to class 1', 'language': 'en'}),
#  Document(page_content='Data for classifying if patients will survive for at least one year after a heart attack', metadata={'Subject Area': 'Life', 'title': 'Echocardiogram', 'source': 'https://archive.ics.uci.edu/dataset/38/echocardiogram', 'description': ' Data for classifying if patients will survive for at least one year after a heart attack', 'language': 'en'}),
#  Document(page_content='DNA codon usage frequencies of a large sample of diverse biological organisms from different taxa', metadata={'Subject Area': 'Life', 'title': 'Codon usage', 'source': 'https://archive.ics.uci.edu/dataset/577/codon+usage', 'description': ' DNA codon usage frequencies of a large sample of diverse biological organisms from different taxa', 'language': 'en'}),
#  Document(page_content='Knight Pin Chess End-Game Database Creator', metadata={'Subject Area': 'Game', 'title': 'Chess (King-Rook vs. King-Knight)', 'source': 'https://archive.ics.uci.edu/dataset/21/chess+king+rook+vs+king+knight', 'description': ' Knight Pin Chess End-Game Database Creator', 'language': 'en'}),
#  Document(page_content='Design an observing network to monitor emissions of a greenhouse gas (GHG) in California given time series of synthetic observations and tracers from weather model simulations.', metadata={'Subject Area': 'Physical', 'title': 'Greenhouse Gas Observing Network', 'source': 'https://archive.ics.uci.edu/dataset/328/greenhouse+gas+observing+network', 'description': ' Design an observing network to monitor emissions of a greenhouse gas (GHG) in California given time series of synthetic observations and tracers from weather model simulations.\n', 'language': 'en'}),
#  Document(page_content='Data in original (LISP-readable) form', metadata={'Subject Area': 'Other', 'title': 'University', 'source': 'https://archive.ics.uci.edu/dataset/104/university', 'description': ' Data in original (LISP-readable) form', 'language': 'en'}),
#  Document(page_content='A cybersecurity dataset containing nine different network attacks on a commercial IP-based surveillance system and an IoT network. The dataset includes reconnaissance, MitM, DoS, and botnet attacks.', metadata={'Subject Area': 'Computer', 'title': 'Kitsune Network Attack Dataset', 'source': 'https://archive.ics.uci.edu/dataset/516/kitsune+network+attack+dataset', 'description': ' A cybersecurity dataset containing nine different network attacks on a commercial IP-based surveillance system and an IoT network. The dataset includes reconnaissance, MitM, DoS, and botnet attacks.', 'language': 'en'}),
#  Document(page_content='Predict a pattern of neurodegeneration in the dataset of speech features obtained from patients with early untreated ParkinsonÃ¢â\x82¬â\x84¢s disease and patients at high risk developing ParkinsonÃ¢â\x82¬â\x84¢s disease.', metadata={'Subject Area': 'Life', 'title': 'Early biomarkers of Parkinsonâ\x80\x99s disease based on natural connected speech', 'source': 'https://archive.ics.uci.edu/dataset/392/early+biomarkers+of+parkinson+s+disease+based+on+natural+connected+speech', 'description': ' Predict a pattern of neurodegeneration in the dataset of speech features obtained from patients with early untreated ParkinsonÃ¢â\x82¬â\x84¢s disease and patients at high risk developing ParkinsonÃ¢â\x82¬â\x84¢s disease.', 'language': 'en'}),
#  Document(page_content="CART book's waveform domains", metadata={'Subject Area': 'Physical', 'title': 'Waveform Database Generator (Version 2)', 'source': 'https://archive.ics.uci.edu/dataset/108/waveform+database+generator+version+2', 'description': " CART book's waveform domains", 'language': 'en'}),
#  Document(page_content='Given a theorem, predict which of five heuristics will give the fastest proof when used by a first-order prover. A sixth prediction declines to attempt a proof, should the theorem be too difficult.', metadata={'Subject Area': 'Computer', 'title': 'First-order theorem proving', 'source': 'https://archive.ics.uci.edu/dataset/249/first+order+theorem+proving', 'description': ' Given a theorem, predict which of five heuristics will give the fastest proof when used by a first-order prover. A sixth prediction declines to attempt a proof, should the theorem be too difficult.', 'language': 'en'}),
#  Document(page_content='This dataset comprises records of 150 subjects (all male employees in Iran have visited the Abadan Occupational (Industrial) Medicine Clinic) and 52 features.', metadata={'Subject Area': 'Life', 'title': 'Nasarian CAD Dataset', 'source': 'https://archive.ics.uci.edu/dataset/557/nasarian+cad+dataset', 'description': ' This dataset comprises records of 150 subjects (all male employees in Iran have visited the Abadan Occupational (Industrial) Medicine Clinic) and 52 features.', 'language': 'en'}),
#  Document(page_content='This is a collection of documents that appeared on Reuters newswire in 1987. The documents were assembled and indexed with categories.', metadata={'Subject Area': 'Business', 'title': 'Reuters-21578 Text Categorization Collection', 'source': 'https://archive.ics.uci.edu/dataset/137/reuters+21578+text+categorization+collection', 'description': ' This is a collection of documents that appeared on Reuters newswire in 1987. The documents were assembled and indexed with categories.', 'language': 'en'}),
#  Document(page_content='Contains permissions extracted from more than 29000 benign & malware Android apps released between 2010-2019.', metadata={'Subject Area': 'Computer Science', 'title': 'NATICUSdroid (Android Permissions) Dataset', 'source': 'https://archive.ics.uci.edu/dataset/722/naticusdroid+android+permissions+dataset', 'description': ' Contains permissions extracted from more than 29000 benign & malware Android apps released between 2010-2019.', 'language': 'en'}),
#  Document(page_content='Experimental data used to create regression models of appliances energy use in a low energy building.', metadata={'Subject Area': 'Computer', 'title': 'Appliances energy prediction', 'source': 'https://archive.ics.uci.edu/dataset/374/appliances+energy+prediction', 'description': ' Experimental data used to create regression models of appliances energy use in a low energy building.', 'language': 'en'}),
#  Document(page_content='This hourly data set contains the PM2.5 data of US Embassy in Beijing. Meanwhile, meteorological data from Beijing Capital International Airport are also included.', metadata={'Subject Area': 'Physical', 'title': 'Beijing PM2.5 Data', 'source': 'https://archive.ics.uci.edu/dataset/381/beijing+pm2+5+data', 'description': ' This hourly data set contains the PM2.5 data of US Embassy in Beijing. Meanwhile, meteorological data from Beijing Capital International Airport are also included. ', 'language': 'en'}),
#  Document(page_content="GISETTE is a handwritten digit recognition problem. The problem is to separate the highly confusible digits '4' and '9'. This dataset is one of five datasets of the NIPS 2003 feature selection challenge.", metadata={'Subject Area': 'Computer', 'title': 'Gisette', 'source': 'https://archive.ics.uci.edu/dataset/170/gisette', 'description': " GISETTE is a handwritten digit recognition problem. The problem is to separate the highly confusible digits '4' and '9'. This dataset is one of five datasets of the NIPS 2003 feature selection challenge.\n", 'language': 'en'}),
#  Document(page_content='This dataset collected mainly from: PhishTank archive, MillerSmiles archive, GoogleÃ¢â\x82¬â\x84¢s searching operators.', metadata={'Subject Area': 'Computer Security', 'title': 'Phishing Websites', 'source': 'https://archive.ics.uci.edu/dataset/327/phishing+websites', 'description': ' This dataset collected mainly from: PhishTank archive, MillerSmiles archive, GoogleÃ¢â\x82¬â\x84¢s searching operators.', 'language': 'en'}),
#  Document(page_content='This dataset is taken from the MiniBooNE experiment and is used to distinguish electron neutrinos (signal) from muon neutrinos (background).', metadata={'Subject Area': 'Physical', 'title': 'MiniBooNE particle identification', 'source': 'https://archive.ics.uci.edu/dataset/199/miniboone+particle+identification', 'description': ' This dataset is taken from the MiniBooNE experiment and is used to distinguish electron neutrinos (signal) from muon neutrinos (background).', 'language': 'en'}),
#  Document(page_content='An introductory dataset presented as an alternative to Iris and useful for teaching data exploration/visualization. Data comes from 3 penguin species in the islands of Palmer Archipelago, Antarctica.', metadata={'Subject Area': 'Life Sciences', 'title': 'Palmer penguins', 'source': 'https://archive.ics.uci.edu/dataset/690/palmer+penguins-3', 'description': ' An introductory dataset presented as an alternative to Iris and useful for teaching data exploration/visualization. Data comes from 3 penguin species in the islands of Palmer Archipelago, Antarctica.', 'language': 'en'}),
#  Document(page_content='The dataset contains 19 attributes regarding ca cervix behavior risk with class label is ca_cervix with 1 and 0 as values which means the respondent with and without ca cervix, respectively.', metadata={'Subject Area': 'Life', 'title': 'Cervical Cancer Behavior Risk', 'source': 'https://archive.ics.uci.edu/dataset/537/cervical+cancer+behavior+risk', 'description': ' The dataset contains 19 attributes regarding ca cervix behavior risk with class label is ca_cervix with 1 and 0 as values which means the respondent with and without ca cervix, respectively.', 'language': 'en'}),
#  Document(page_content='Google reviews on attractions from 24 categories across Europe are considered. Google user rating ranges from 1 to 5 and average user rating per category is calculated.', metadata={'Subject Area': 'Other', 'title': 'Tarvel Review Ratings', 'source': 'https://archive.ics.uci.edu/dataset/485/tarvel+review+ratings', 'description': ' Google reviews on attractions from 24 categories across Europe are considered. Google user rating ranges from 1 to 5 and average user rating per category is calculated.', 'language': 'en'}),
#  Document(page_content='Data on sponges; Attributes in spanish', metadata={'Subject Area': 'Life', 'title': 'Sponge', 'source': 'https://archive.ics.uci.edu/dataset/97/sponge', 'description': ' Data on sponges; Attributes in spanish', 'language': 'en'}),
#  Document(page_content='The Human Activity Recognition 70+ (HAR70+) dataset is a professionally-annotated dataset containing 18 fit-to-frail older-adult subjects (70-95 years old) wearing two 3-axial accelerometers for around 40 minutes during a semi-structured free-living protocol. The sensors were attached to the right thigh and lower back.', metadata={'Subject Area': 'Computer Science', 'title': 'HAR70+', 'source': 'https://archive.ics.uci.edu/dataset/780/har70', 'description': ' The Human Activity Recognition 70+ (HAR70+) dataset is a professionally-annotated dataset containing 18 fit-to-frail older-adult subjects (70-95 years old) wearing two 3-axial accelerometers for around 40 minutes during a semi-structured free-living protocol. The sensors were attached to the right thigh and lower back. ', 'language': 'en'}),
# ...
#  Document(page_content='This dataset is an image segmentation database similar to a database already present in the repository (Image segmentation database) but in a slightly different form.', metadata={'Subject Area': 'Other', 'title': 'Statlog (Image Segmentation)', 'source': 'https://archive.ics.uci.edu/dataset/147/statlog+image+segmentation', 'description': ' This dataset is an image segmentation database similar to a database already present in the repository (Image segmentation database) but in a slightly different form.', 'language': 'en'}),
#  Document(page_content='Speaker independent recognition of the eleven steady state vowels of British English using a specified training set of lpc derived log area ratios.', metadata={'Subject Area': 'Other', 'title': 'Connectionist Bench (Vowel Recognition - Deterding Data)', 'source': 'https://archive.ics.uci.edu/dataset/152/connectionist+bench+vowel+recognition+deterding+data', 'description': ' Speaker independent recognition of the eleven steady state vowels of British English using a specified training set of lpc derived log area ratios.', 'language': 'en'}),
#  Document(page_content='Data have been generated from a sophisticated simulator of a Gas Turbines (GT), mounted on a Frigate characterized by a COmbined Diesel eLectric And Gas (CODLAG) propulsion plant type.', metadata={'Subject Area': 'Computer', 'title': 'Condition Based Maintenance of Naval Propulsion Plants', 'source': 'https://archive.ics.uci.edu/dataset/316/condition+based+maintenance+of+naval+propulsion+plants', 'description': ' Data have been generated from a sophisticated simulator of a Gas Turbines (GT), mounted on a Frigate characterized by a COmbined Diesel eLectric And Gas (CODLAG) propulsion plant type.', 'language': 'en'}),
#  Document(page_content="This dataset achieved from an online survey, which is run by UNSW, Australia. It contains three data of ' Flocking - Not Flocking', 'Aligned - Not Aligned', and 'Grouped - Not Grouped'.", metadata={'Subject Area': 'Computer', 'title': 'Swarm Behaviour', 'source': 'https://archive.ics.uci.edu/dataset/524/swarm+behaviour', 'description': " This dataset achieved from an online survey, which is run by UNSW, Australia. It contains three data of ' Flocking - Not Flocking', 'Aligned - Not Aligned', and 'Grouped - Not Grouped'.", 'language': 'en'}),
#  Document(page_content='This dataset include data for the estimation of obesity levels in individuals from the countries of Mexico, Peru and Colombia, based on their eating habits and physical condition.', metadata={'Subject Area': 'Life', 'title': 'Estimation of obesity levels based on eating habits and physical condition ', 'source': 'https://archive.ics.uci.edu/dataset/544/estimation+of+obesity+levels+based+on+eating+habits+and+physical+condition', 'description': ' This dataset include data for the estimation of obesity levels in individuals from the countries of Mexico, Peru and Colombia, based on their eating habits and physical condition. ', 'language': 'en'}),
#  Document(page_content='A well-known large-scale image classification dataset with between 1000 and 20000 class labels and multiple million images.', metadata={'Subject Area': 'Computer Science', 'title': 'ImageNet', 'source': 'https://archive.ics.uci.edu/dataset/693/imagenet', 'description': ' A well-known large-scale image classification dataset with between 1000 and 20000 class labels and multiple million images.', 'language': 'en'}),
#  Document(page_content='These are files of raw EMG data recorded by MYO Thalmic bracelet', metadata={'Subject Area': 'Life', 'title': 'EMG data for gestures', 'source': 'https://archive.ics.uci.edu/dataset/481/emg+data+for+gestures', 'description': ' These are files of raw EMG data recorded by MYO Thalmic bracelet', 'language': 'en'}),
#  Document(page_content='This dataset contains data of the candidates who qualified the medical entrance examination for admission to medical colleges of Assam of a particular year and collected by Prof. Jiten Hazarika.', metadata={'Subject Area': 'Computer', 'title': 'Student Performance on an entrance examination', 'source': 'https://archive.ics.uci.edu/dataset/582/student+performance+on+an+entrance+examination', 'description': ' This dataset contains data of the candidates who qualified the medical entrance examination for admission to medical colleges of Assam of a particular year and collected by Prof. Jiten Hazarika.', 'language': 'en'}),
#  Document(page_content='Bilateral (left, right) joint angle (ankle, knee, hip) times series data collected from 10 healthy subjects under 3 walking conditions (unbraced, knee braced, ankle braced). For each condition, each subjectâ\x80\x99s data consists of 10 consecutive gait cycles.', metadata={'Subject Area': 'Life Science', 'title': 'Multivariate Gait Data', 'source': 'https://archive.ics.uci.edu/dataset/760/multivariate+gait+data', 'description': ' Bilateral (left, right) joint angle (ankle, knee, hip) times series data collected from 10 healthy subjects under 3 walking conditions (unbraced, knee braced, ankle braced). For each condition, each subjectâ\x80\x99s data consists of 10 consecutive gait cycles.', 'language': 'en'}),
#  Document(page_content='Data are MC generated to simulate registration of high energy gamma particles in an atmospheric Cherenkov telescope', metadata={'Subject Area': 'Physical', 'title': 'MAGIC Gamma Telescope', 'source': 'https://archive.ics.uci.edu/dataset/159/magic+gamma+telescope', 'description': ' Data are MC generated to simulate registration of high energy gamma particles in an atmospheric Cherenkov telescope', 'language': 'en'}),
#  Document(page_content='Data set featuring single English words read by speakers from six different countries for accent detection and recognition', metadata={'Subject Area': 'Social', 'title': 'Speaker Accent Recognition', 'source': 'https://archive.ics.uci.edu/dataset/518/speaker+accent+recognition', 'description': ' Data set featuring single English words read by speakers from six different countries for accent detection and recognition', 'language': 'en'}),
#  Document(page_content='This dataset contains wearable inertial and magnetic sensor data during the execution of physical therapy exercises. There are eight types of physical therapy exercises, each of which has three execution types (correct, fast, and low-amplitude). Each execution type of each type of exercise was performed multiple times by five subjects. The subjects wore five MTx sensor units manufactured by XSens. Each unit contains three tri-axial sensors: an accelerometer, a gyroscope, and a magnetometer, sampled at 25 Hz.', metadata={'Subject Area': 'Engineering', 'title': 'Physical Therapy Exercises Dataset', 'source': 'https://archive.ics.uci.edu/dataset/730/physical+therapy+exercises+dataset', 'description': ' This dataset contains wearable inertial and magnetic sensor data during the execution of physical therapy exercises. There are eight types of physical therapy exercises, each of which has three execution types (correct, fast, and low-amplitude). Each execution type of each type of exercise was performed multiple times by five subjects. The subjects wore five MTx sensor units manufactured by XSens. Each unit contains three tri-axial sensors: an accelerometer, a gyroscope, and a magnetometer, sampled at 25 Hz.', 'language': 'en'}),
#  Document(page_content="Amazon's InfoSec is getting smarter about the way Access data is leveraged. This is an anonymized sample of access provisioned within the company.", metadata={'Subject Area': 'Business', 'title': 'Amazon Access Samples', 'source': 'https://archive.ics.uci.edu/dataset/216/amazon+access+samples', 'description': " Amazon's InfoSec is getting smarter about the way Access data is leveraged. This is an anonymized sample of access provisioned within the company.", 'language': 'en'}),
#  Document(page_content='This is a classification problem to distinguish between a signal process which produces Higgs bosons and a background process which does not.', metadata={'Subject Area': 'Physical', 'title': 'HIGGS', 'source': 'https://archive.ics.uci.edu/dataset/280/higgs', 'description': ' This is a classification problem to distinguish between a signal process which produces Higgs bosons and a background process which does not. ', 'language': 'en'}),
#  Document(page_content='This dataset contains information about caesarian section results of  80 pregnant women with the most important characteristics of delivery problems in the medical field.', metadata={'Subject Area': 'Life', 'title': 'Caesarian Section Classification Dataset', 'source': 'https://archive.ics.uci.edu/dataset/472/caesarian+section+classification+dataset', 'description': ' This dataset contains information about caesarian section results of  80 pregnant women with the most important characteristics of delivery problems in the medical field.', 'language': 'en'}),
#  Document(page_content='This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.', metadata={'Subject Area': 'Business', 'title': 'Online Retail', 'source': 'https://archive.ics.uci.edu/dataset/352/online+retail', 'description': ' This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.', 'language': 'en'}),
#  Document(page_content='Autistic Spectrum Disorder Screening Data for Adult. This dataset is related to classification and predictive tasks.', metadata={'Subject Area': 'Social', 'title': 'Autism Screening Adult', 'source': 'https://archive.ics.uci.edu/dataset/426/autism+screening+adult', 'description': ' Autistic Spectrum Disorder Screening Data for Adult. This dataset is related to classification and predictive tasks.', 'language': 'en'}),
#  Document(page_content='15 months worth of daily data (440 daily records) that describes the occupancy rate, between 0 and 1, of different car lanes of the San Francisco bay area freeways across time.', metadata={'Subject Area': 'Computer', 'title': 'PEMS-SF', 'source': 'https://archive.ics.uci.edu/dataset/204/pems+sf', 'description': ' 15 months worth of daily data (440 daily records) that describes the occupancy rate, between 0 and 1, of different car lanes of the San Francisco bay area freeways across time.', 'language': 'en'}),
#  Document(page_content='The Physical Action Data Set includes 10 normal and 10 aggressive physical actions that measure the human activity. The data have been collected by 10 subjects using the Vicon 3D tracker.', metadata={'Subject Area': 'Physical', 'title': 'Vicon Physical Action Data Set', 'source': 'https://archive.ics.uci.edu/dataset/214/vicon+physical+action+data+set', 'description': ' The Physical Action Data Set includes 10 normal and 10 aggressive physical actions that measure the human activity. The data have been collected by 10 subjects using the Vicon 3D tracker.', 'language': 'en'}),
#  Document(page_content='First self-care activities dataset based on ICF-CY.', metadata={'Subject Area': 'Life', 'title': 'SCADI', 'source': 'https://archive.ics.uci.edu/dataset/446/scadi', 'description': ' First self-care activities dataset based on ICF-CY.', 'language': 'en'}),
#  Document(page_content='From Classification and Regression Trees book; We provide here 2 C programs for generating sample databases', metadata={'Subject Area': 'Computer', 'title': 'LED Display Domain', 'source': 'https://archive.ics.uci.edu/dataset/57/led+display+domain', 'description': ' From Classification and Regression Trees book; We provide here 2 C programs for generating sample databases', 'language': 'en'}),
#  Document(page_content='The dataset is provided by the Ã¢â\x82¬Å\x93Trialto Latvia LTDÃ¢â\x82¬Â\x9d, the third-party logistics operator. Each observation stands for a distinct type of item for sale.', metadata={'Subject Area': 'Business', 'title': 'Stock keeping units', 'source': 'https://archive.ics.uci.edu/dataset/585/stock+keeping+units', 'description': ' The dataset is provided by the Ã¢â\x82¬Å\x93Trialto Latvia LTDÃ¢â\x82¬Â\x9d, the third-party logistics operator. Each observation stands for a distinct type of item for sale. ', 'language': 'en'}),
#  Document(page_content='A social network of LastFM users from Asian countries. The related task is predicting the country of origin based on social relations and artists liked.', metadata={'Subject Area': 'Social', 'title': 'LastFM Asia Social Network', 'source': 'https://archive.ics.uci.edu/dataset/595/lastfm+asia+social+network', 'description': ' A social network of LastFM users from Asian countries. The related task is predicting the country of origin based on social relations and artists liked.', 'language': 'en'}),
#  Document(page_content='This data set consists of positions and absorbed power outputs of wave energy converters (WECs) in four real wave scenarios from the southern coast of Australia.', metadata={'Subject Area': 'Computer', 'title': 'Wave Energy Converters', 'source': 'https://archive.ics.uci.edu/dataset/534/wave+energy+converters', 'description': ' This data set consists of positions and absorbed power outputs of wave energy converters (WECs) in four real wave scenarios from the southern coast of Australia. ', 'language': 'en'}),
#  Document(page_content='Accelerometer and transdermal alcohol content data from a college bar crawl. Used to predict heavy drinking episodes via mobile data.', metadata={'Subject Area': 'Life', 'title': 'Bar Crawl: Detecting Heavy Drinking', 'source': 'https://archive.ics.uci.edu/dataset/559/bar+crawl+detecting+heavy+drinking', 'description': ' Accelerometer and transdermal alcohol content data from a college bar crawl. Used to predict heavy drinking episodes via mobile data.', 'language': 'en'}),
#  Document(page_content='Participants completed the Personal Information Form and Divorce Predictors Scale.', metadata={'Subject Area': 'Life', 'title': 'Divorce Predictors data set', 'source': 'https://archive.ics.uci.edu/dataset/497/divorce+predictors+data+set', 'description': ' Participants completed the Personal Information Form and Divorce Predictors Scale. ', 'language': 'en'}),
#  Document(page_content='597 de-identified raw X-ray scans of implanted shoulder prostheses from four manufactures.', metadata={'Subject Area': 'Life', 'title': 'Shoulder Implant X-Ray Manufacturer Classification', 'source': 'https://archive.ics.uci.edu/dataset/517/shoulder+implant+x+ray+manufacturer+classification', 'description': ' 597 de-identified raw X-ray scans of implanted shoulder prostheses from four manufactures.', 'language': 'en'}),
#  Document(page_content='This repository introduces a novel dataset for the classification of 4 groups of respiratory diseases: Chronic Obstructive Pulmonary Disease (COPD), asthma, infected, and Healthy Controls (HC).', metadata={'Subject Area': 'Life', 'title': 'Exasens', 'source': 'https://archive.ics.uci.edu/dataset/523/exasens', 'description': ' This repository introduces a novel dataset for the classification of 4 groups of respiratory diseases: Chronic Obstructive Pulmonary Disease (COPD), asthma, infected, and Healthy Controls (HC).', 'language': 'en'}),
#  Document(page_content='Contains the responses of a gas multisensor device deployed on the field in an Italian city. Hourly responses averages are recorded along with gas concentrations references from a certified analyzer.', metadata={'Subject Area': 'Computer', 'title': 'Air Quality', 'source': 'https://archive.ics.uci.edu/dataset/360/air+quality', 'description': ' Contains the responses of a gas multisensor device deployed on the field in an Italian city. Hourly responses averages are recorded along with gas concentrations references from a certified analyzer. ', 'language': 'en'})]

# %% [markdown]
# ## Create embedding model

# %%
# !pip install -q sentence-transformers
# !pip install -q langchain

from langchain.embeddings import HuggingFaceEmbeddings
import torch

model_name = "sentence-transformers/all-MiniLM-L6-v2" # all-MiniLM-L6-v2: structure of SBert
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': False}
embed_model = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

# %% [markdown]
# ## Create vector store

# %%
# note the `embedding` argument is not the embedded value but the embedding model

from langchain.vectorstores import Milvus

vector_store = Milvus.from_documents(
    docs_split,
    embedding=embed_model,
    connection_args={"host": MILVUS_HOST, "port": MILVUS_PORT}
)
# Out:
# Batches:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
vector_store

# %% [markdown]
# ## Similarity Searches

# %%
# Try text-to-text similarity searches 

query1 = "Can I find a dataset of newspapers and magazines in Russian?"
docs1 = vector_store.similarity_search(query1)

print(docs1)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [Document(page_content='Dataset is well suited for segmentation tasks. It contains 101 scanned pages from different newspapers and magazines in Russian with ground truth pixel-based masks.', metadata={'source': 'https://archive.ics.uci.edu/dataset/306/newspaper+and+magazine+images+segmentation+dataset', 'title': 'Newspaper and magazine images segmentation dataset', 'description': ' Dataset is well suited for segmentation tasks. It contains 101 scanned pages from different newspapers and magazines in Russian with ground truth pixel-based masks.', 'language': 'en'}), Document(page_content='Dataset is well suited for segmentation tasks. It contains 101 scanned pages from different newspapers and magazines in Russian with ground truth pixel-based masks.', metadata={'source': 'https://archive.ics.uci.edu/dataset/306/newspaper+and+magazine+images+segmentation+dataset', 'title': 'Newspaper and magazine images segmentation dataset', 'description': ' Dataset is well suited for segmentation tasks. It contains 101 scanned pages from different newspapers and magazines in Russian with ground truth pixel-based masks.', 'language': 'en'}), Document(page_content='Dataset is well suited for segmentation tasks. It contains 101 scanned pages from different newspapers and magazines in Russian with ground truth pixel-based masks.', metadata={'source': 'https://archive.ics.uci.edu/dataset/306/newspaper+and+magazine+images+segmentation+dataset', 'title': 'Newspaper and magazine images segmentation dataset', 'description': ' Dataset is well suited for segmentation tasks. It contains 101 scanned pages from different newspapers and magazines in Russian with ground truth pixel-based masks.', 'language': 'en'}), Document(page_content='This is a collection of documents that appeared on Reuters newswire in 1987. The documents were assembled and indexed with categories.', metadata={'source': 'https://archive.ics.uci.edu/dataset/137/reuters+21578+text+categorization+collection', 'title': 'Reuters-21578 Text Categorization Collection', 'description': ' This is a collection of documents that appeared on Reuters newswire in 1987. The documents were assembled and indexed with categories.', 'language': 'en'})]

# %%
# Try text-to-text similarity searches 

query2 = "Can I find a dataset of old films?"
docs2 = vector_store.similarity_search(query2)

print(docs2)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [Document(page_content='This data set contains a list of over 10000 films including many older, odd, and cult films. There is information on actors, casts, directors, producers, studios, etc.', metadata={'source': 'https://archive.ics.uci.edu/dataset/132/movie', 'title': 'Movie', 'description': ' This data set contains a list of over 10000 films including many older, odd, and cult films. There is information on actors, casts, directors, producers, studios, etc.', 'language': 'en'}), Document(page_content='This data set contains a list of over 10000 films including many older, odd, and cult films. There is information on actors, casts, directors, producers, studios, etc.', metadata={'source': 'https://archive.ics.uci.edu/dataset/132/movie', 'title': 'Movie', 'description': ' This data set contains a list of over 10000 films including many older, odd, and cult films. There is information on actors, casts, directors, producers, studios, etc.', 'language': 'en'}), Document(page_content='This data set contains a list of over 10000 films including many older, odd, and cult films. There is information on actors, casts, directors, producers, studios, etc.', metadata={'source': 'https://archive.ics.uci.edu/dataset/132/movie', 'title': 'Movie', 'description': ' This data set contains a list of over 10000 films including many older, odd, and cult films. There is information on actors, casts, directors, producers, studios, etc.', 'language': 'en'}), Document(page_content='Various datasets without documentation (feel free to explore!)', metadata={'source': 'https://archive.ics.uci.edu/dataset/112/undocumented', 'title': 'Undocumented', 'description': ' Various datasets without documentation (feel free to explore!)', 'language': 'en'})]

# %% [markdown]
# ## ---------------------------- End of file ----------------------------

# %% [markdown]
# ## Appendix: WebBaseLoader in the tutorial example

# %% [markdown]
# tutorial: https://milvus.io/docs/integrate_with_langchain.md

# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader([
    "https://milvus.io/docs/overview.md",
])

docs_example = loader.load()

# %%
type(docs_example)
# Out:
# list

# %%
docs_example
# Out:
# [Document(page_content="Introduction Milvus documentationDocsTutorialsToolsBlogCommunityStars0Join SlackTry Managed Milvus FREESearchHomev2.2.x\u200bAbout MilvusWhat is MilvusMilvus AdoptersMilvus RoadmapMilvus LimitsReleasesEnhancement ProposalsBootcampGet StartedUser GuideAdministration GuideIntegrationsBenchmarksToolsReferenceExample ApplicationsFAQsAPI referenceIntroduction\nThis page aims to give you an overview of Milvus by answering several questions. After reading this page, you will learn what Milvus is and how it works, as well as the key concepts, why use Milvus, supported indexes and metrics, example applications, the architecture, and relevant tools.\nWhat is Milvus vector database?\nMilvus was created in 2019 with a singular goal: store, index, and manage massive embedding vectors generated by deep neural networks and other machine learning (ML) models.\nAs a database specifically designed to handle queries over input vectors, it is capable of indexing vectors on a trillion scale. Unlike existing relational databases which mainly deal with structured data following a pre-defined pattern, Milvus is designed from the bottom-up to handle embedding vectors converted from unstructured data.\nAs the Internet grew and evolved, unstructured data became more and more common, including emails, papers, IoT sensor data, Facebook photos, protein structures, and much more. In order for computers to understand and process unstructured data, these are converted into vectors using embedding techniques. Milvus stores and indexes these vectors. Milvus is able to analyze the correlation between two vectors by calculating their similarity distance. If the two embedding vectors are very similar, it means that the original data sources are similar as well.\n\n\n\n\n\n\n\nMilvus workflow.\n\nKey concepts\nIn case you are new to the world of vector database and similarity search, read the following explanation of key concepts to gain a better understanding.\nLearn more about Milvus glossary.\nUnstructured data\nUnstructured data, including images, video, audio, and natural language, is information that doesn't follow a pre-defined model or manner of organization. This data type accounts for around 80% of the world's data, and can be converted into vectors using various artificial intelligence (AI) and machine learning (ML) models.\nEmbedding vectors\nAn embedding vector is a feature abstraction of unstructured data, such as emails, IoT sensor data, Instagram photos, protein structures, and much more. Mathematically speaking, an embedding vector is an array of floating-point numbers or binaries. Modern embedding techniques are used to convert unstructured data to embedding vectors.\nVector similarity search\nVector similarity search is the process of comparing a vector to a database to find vectors that are most similar to the query vector. Approximate nearest neighbor (ANN) search algorithms are used to accelerate the searching process. If the two embedding vectors are very similar, it means that the original data sources are similar as well.\nWhy Milvus?\n\nHigh performance when conducting vector search on massive datasets.\nA developer-first community that offers multi-language support and toolchain.\nCloud scalability and high reliability even in the event of a disruption.\nHybrid search achieved by pairing scalar filtering with vector similarity search.\n\nWhat indexes and metrics are supported?\nIndexes are an organization unit of data. You must declare the index type and similarity metric before you can search or query inserted entities. If you do not specify an index type, Milvus will operate brute-force search by default.\nIndex types\nMost of the vector index types supported by Milvus use approximate nearest neighbors search (ANNS), including:\n\nFLAT: FLAT is best suited for scenarios that seek perfectly accurate and exact search results on a small, million-scale dataset.\nIVF_FLAT: IVF_FLAT is a quantization-based index and is ...

# %%
text_splitter = CharacterTextSplitter(chunk_size=1024, chunk_overlap=0)
docs_example = text_splitter.split_documents(docs_example)
# Out:
# Created a chunk of size 1743, which is longer than the specified 1024
# Created a chunk of size 1278, which is longer than the specified 1024

# %%
docs_example
# Out:
# [Document(page_content='Introduction Milvus documentationDocsTutorialsToolsBlogCommunityStars0Join SlackTry Managed Milvus FREESearchHomev2.2.x\u200bAbout MilvusWhat is MilvusMilvus AdoptersMilvus RoadmapMilvus LimitsReleasesEnhancement ProposalsBootcampGet StartedUser GuideAdministration GuideIntegrationsBenchmarksToolsReferenceExample ApplicationsFAQsAPI referenceIntroduction\nThis page aims to give you an overview of Milvus by answering several questions. After reading this page, you will learn what Milvus is and how it works, as well as the key concepts, why use Milvus, supported indexes and metrics, example applications, the architecture, and relevant tools.\nWhat is Milvus vector database?\nMilvus was created in 2019 with a singular goal: store, index, and manage massive embedding vectors generated by deep neural networks and other machine learning (ML) models.\nAs a database specifically designed to handle queries over input vectors, it is capable of indexing vectors on a trillion scale. Unlike existing relational databases which mainly deal with structured data following a pre-defined pattern, Milvus is designed from the bottom-up to handle embedding vectors converted from unstructured data.\nAs the Internet grew and evolved, unstructured data became more and more common, including emails, papers, IoT sensor data, Facebook photos, protein structures, and much more. In order for computers to understand and process unstructured data, these are converted into vectors using embedding techniques. Milvus stores and indexes these vectors. Milvus is able to analyze the correlation between two vectors by calculating their similarity distance. If the two embedding vectors are very similar, it means that the original data sources are similar as well.', metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}),
#  Document(page_content='Milvus workflow.', metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}),
#  Document(page_content="Key concepts\nIn case you are new to the world of vector database and similarity search, read the following explanation of key concepts to gain a better understanding.\nLearn more about Milvus glossary.\nUnstructured data\nUnstructured data, including images, video, audio, and natural language, is information that doesn't follow a pre-defined model or manner of organization. This data type accounts for around 80% of the world's data, and can be converted into vectors using various artificial intelligence (AI) and machine learning (ML) models.\nEmbedding vectors\nAn embedding vector is a feature abstraction of unstructured data, such as emails, IoT sensor data, Instagram photos, protein structures, and much more. Mathematically speaking, an embedding vector is an array of floating-point numbers or binaries. Modern embedding techniques are used to convert unstructured data to embedding vectors.\nVector similarity search\nVector similarity search is the process of comparing a vector to a database to find vectors that are most similar to the query vector. Approximate nearest neighbor (ANN) search algorithms are used to accelerate the searching process. If the two embedding vectors are very similar, it means that the original data sources are similar as well.\nWhy Milvus?", metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}),
#  Document(page_content='High performance when conducting vector search on massive datasets.\nA developer-first community that offers multi-language support and toolchain.\nCloud scalability and high reliability even in the event of a disruption.\nHybrid search achieved by pairing scalar filtering with vector similarity search.\n\nWhat indexes and metrics are supported?\nIndexes are an organization unit of data. You must declare the index type and similarity metric before you can search or query inserted entities. If you do not specify an index type, Milvus will operate brute-force search by default.\nIndex types\nMost of the vector index types supported by Milvus use approximate nearest neighbors search (ANNS), including:', metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}),
#  Document(page_content='FLAT: FLAT is best suited for scenarios that seek perfectly accurate and exact search results on a small, million-scale dataset.\nIVF_FLAT: IVF_FLAT is a quantization-based index and is best suited for scenarios that seek an ideal balance between accuracy and query speed.\nIVF_SQ8: IVF_SQ8 is a quantization-based index and is best suited for scenarios that seek a significant reduction on disk, CPU, and GPU memory consumption as these resources are very limited.\nIVF_PQ: IVF_PQ is a quantization-based index and is best suited for scenarios that seek high query speed even at the cost of accuracy.\nHNSW: HNSW is a graph-based index and is best suited for scenarios that have a high demand for search efficiency.\nANNOY: ANNOY is a tree-based index and is best suited for scenarios that seek a high recall rate.', metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}),
#  Document(page_content='See Vector Index for more details.\nSimilarity metrics\nIn Milvus, similarity metrics are used to measure similarities among vectors. Choosing a good distance metric helps improve classification and clustering performance significantly. Depending on the input data forms, specific similarity metric is selected for optimal performance.\nThe metrics that are widely used for floating point embeddings include:\n\nEuclidean distance (L2): This metric is generally used in the field of computer vision (CV).\nInner product (IP): This metric is generally used in the field of natural language processing (NLP).\n\nThe metrics that are widely used for binary embeddings include:', metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}),
#  Document(page_content='Hamming: This metric is generally used in the field of natural language processing (NLP).\nJaccard: This metric is generally used in the field of molecular similarity search.\nTanimoto: This metric is generally used in the field of molecular similarity search.\nSuperstructure: This metric is generally used to search for similar superstructure of a molecule.\nSubstructure: This metric is generally used  to search for similar substructure of a molecule.\n\nSee Similarity Metrics for more information.\nExample applications\nMilvus makes it easy to add similarity search to your applications. Example applications of Milvus include:', metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}),
#  Document(page_content='Image similarity search: Images made searchable and instantaneously return the most similar images from a massive database.\nVideo similarity search: By converting key frames into vectors and then feeding the results into Milvus, billions of videos can be searched and recommended in near real-time.\nAudio similarity search: Quickly query massive volumes of audio data such as speech, music, sound effects, and surface similar sounds.\nMolecular similarity search: Blazing fast similarity search, substructure search, or superstructure search for a specified molecule.\nRecommender system: Recommend information or products based on user behaviors and needs.\nQuestion answering system: Interactive digital QA chatbot that automatically answers user questions.\nDNA sequence classification: Accurately sort out the classification of a gene in milliseconds by comparing similar DNA sequence.\nText search engine: Help users find the information they are looking for by comparing keywords against a database of texts.', metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}),
#  Document(page_content="See Milvus tutorials and Milvus Adopters for more Milvus application scenarios.\nHow is Milvus designed?\nAs a cloud-native vector database, Milvus separates storage and computation by design. To enhance elasticity and flexibility, all components in Milvus are stateless.\nThe system breaks down into four levels:\n\nAccess layer: The access layer is composed of a group of stateless proxies and serves as the front layer of the system and endpoint to users.\nCoordinator service: The coordinator service assigns tasks to the worker nodes and functions as the system's brain.\nWorker nodes: The worker nodes function as arms and legs and are dumb executors that follow instructions from the coordinator service and execute user-triggered DML/DDL commands.\nStorage: Storage is the bone of the system, and is responsible for data persistence. It comprises meta storage, log broker, and object storage.\n\nFor more information, see Architecture Overview.\n\nMilvus architecure.", metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}),
#  Document(page_content="Developer tools\nMilvus is supported by rich APIs and tools to facilitate DevOps.\nAPI access\nMilvus has client libraries wrapped on top of the Milvus API that can be used to insert, delete, and query data programmatically from application code:\n\nPyMilvus\nNode.js SDK\nGo SDK\nJava SDK\n\nWe are working on enabling more new client libraries. If you would like to contribute, go to the corresponding repository of the Milvus Project.\nMilvus ecosystem tools\nThe Milvus ecosystem provides helpful tools including:\n\nMilvus CLI\nAttu, a graphical management system for Milvus.\nMilvusDM (Milvus Data Migration), an open-source tool designed specifically for importing and exporting data with Milvus.\nMilvus sizing tool, which helps you estimate the raw file size, memory size, and stable disk size needed for a specified number of vectors with various index types.\n\nWhat's next\n\nGet started with a 3-minute tutorial:\n\nHello Milvus\n\n\nInstall Milvus for your testing or production environment:", metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}),
#  Document(page_content="Installation Prerequisites\nInstall Milvus Standalone\n\n\nIf you're interested in diving deep into the design details of Milvus:\n\nRead about Milvus architecture\n\n\nEdit this pageReport a bugRequest doc changesOn this pageIntroductionWhat is Milvus vector database?Key conceptsWhy Milvus?What indexes and metrics are supported?Example applicationsHow is Milvus designed?Developer toolsWhat's nextResourcesDocsBlogManaged serviceTutorialsBootcampDemoVideoToolsAttuMilvus CLISizing ToolMivlus backup ToolCommunityGet involvedSlackGithubForumMilvus. 2023 All rights reserved.", metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'})]

# %%
# Embedding

# embeddings = OpenAIEmbeddings(model="ada")

# !pip install -q sentence-transformers
# !pip install -q langchain

from langchain.embeddings import HuggingFaceEmbeddings
import torch

model_name = "sentence-transformers/all-MiniLM-L6-v2" # all-MiniLM-L6-v2: structure of SBert
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': False}
embed_model = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
vector_store = Milvus.from_documents(
    docs_example,
    embedding=embed_model,
    connection_args={"host": MILVUS_HOST, "port": MILVUS_PORT}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Try text-to-text similarity searches 

query = "What is milvus?"
docs = vector_store.similarity_search(query)

print(docs)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [Document(page_content='Milvus workflow.', metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}), Document(page_content='Milvus workflow.', metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}), Document(page_content="Installation Prerequisites\nInstall Milvus Standalone\n\n\nIf you're interested in diving deep into the design details of Milvus:\n\nRead about Milvus architecture\n\n\nEdit this pageReport a bugRequest doc changesOn this pageIntroductionWhat is Milvus vector database?Key conceptsWhy Milvus?What indexes and metrics are supported?Example applicationsHow is Milvus designed?Developer toolsWhat's nextResourcesDocsBlogManaged serviceTutorialsBootcampDemoVideoToolsAttuMilvus CLISizing ToolMivlus backup ToolCommunityGet involvedSlackGithubForumMilvus. 2023 All rights reserved.", metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'}), Document(page_content="Installation Prerequisites\nInstall Milvus Standalone\n\n\nIf you're interested in diving deep into the design details of Milvus:\n\nRead about Milvus architecture\n\n\nEdit this pageReport a bugRequest doc changesOn this pageIntroductionWhat is Milvus vector database?Key conceptsWhy Milvus?What indexes and metrics are supported?Example applicationsHow is Milvus designed?Developer toolsWhat's nextResourcesDocsBlogManaged serviceTutorialsBootcampDemoVideoToolsAttuMilvus CLISizing ToolMivlus backup ToolCommunityGet involvedSlackGithubForumMilvus. 2023 All rights reserved.", metadata={'source': 'https://milvus.io/docs/overview.md', 'title': 'Introduction Milvus documentation', 'description': 'Milvus is an open-source vector database designed specifically for AI application development, embeddings similarity search, and MLOps v2.2.x.', 'language': 'en'})]
